# %%
pip install -U finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.96-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.2/48.2 kB ? eta 0:00:00
# Requirement already satisfied: requests>=2.3.0 in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (2.28.1)
# Requirement already satisfied: plotly in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: lxml in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (1.5.2)
# Requirement already satisfied: requests-file in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\lopin\anaconda3\lib\site-packages (from finance-datareader) (4.11.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\lopin\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lopin\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lopin\anaconda3\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2022.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lopin\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2024.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lopin\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lopin\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lopin\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lopin\anaconda3\lib\site-packages (from beautifulsoup4->finance-datareader) (2.3.2.post1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lopin\anaconda3\lib\site-packages (from plotly->finance-datareader) (8.0.1)
# Requirement already satisfied: six in c:\users\lopin\anaconda3\lib\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\lopin\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.4)
# Installing collected packages: finance-datareader
# Successfully installed finance-datareader-0.9.96
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr
import pandas as pd
import time

# 1. KRX 종목 리스트 가져오기
df_krx = fdr.StockListing('KRX')

# 2. 모든 종목 데이터를 저장할 리스트 생성
all_data = []

# 3. 종목별 데이터 가져오기
for code, name in zip(df_krx['Code'], df_krx['Name']):
    try:
        print(f"Fetching {name} ({code})...")
        df = fdr.DataReader(code)  # 주가 데이터 가져오기
        df['Code'] = code  # 종목 코드 추가
        df['Name'] = name  # 종목명 추가
        all_data.append(df)
        
    except Exception as e:
        print(f"Failed to fetch {name} ({code}): {e}")

# 4. 하나의 DataFrame으로 합치기
if all_data:
    final_df = pd.concat(all_data)
    
    # CSV 파일로 저장
    final_df.to_csv('krx_stock_data.csv', encoding='utf-8-sig')
    print("CSV 저장 완료: krx_stock_data.csv")
else:
    print("데이터가 없습니다.")
# Out:
# Fetching 삼성전자 (005930)...
# Fetching SK하이닉스 (000660)...
# Fetching LG에너지솔루션 (373220)...
# Fetching 삼성바이오로직스 (207940)...
# Fetching 현대차 (005380)...
# Fetching 셀트리온 (068270)...
# Fetching 기아 (000270)...
# Fetching 삼성전자우 (005935)...
# Fetching NAVER (035420)...
# Fetching 한화에어로스페이스 (012450)...
# Fetching KB금융 (105560)...
# Fetching HD현대중공업 (329180)...
# Fetching POSCO홀딩스 (005490)...
# Fetching 현대모비스 (012330)...
# Fetching 신한지주 (055550)...
# Fetching 한화오션 (042660)...
# Fetching 메리츠금융지주 (138040)...
# Fetching 알테오젠 (196170)...
# Fetching 삼성물산 (028260)...
# Fetching SK이노베이션 (096770)...
# Fetching 카카오 (035720)...
# Fetching 고려아연 (010130)...
# Fetching HMM (011200)...
# Fetching 삼성화재 (000810)...
# Fetching 하나금융지주 (086790)...
# Fetching 두산에너빌리티 (034020)...
# Fetching 크래프톤 (259960)...
# Fetching 삼성생명 (032830)...
# Fetching LG화학 (051910)...
# Fetching HD한국조선해양 (009540)...
# Fetching 한국전력 (015760)...
# Fetching LG전자 (066570)...
# Fetching 삼성SDI (006400)...
# Fetching 삼성중공업 (010140)...
# Fetching 기업은행 (024110)...
# Fetching SK스퀘어 (402340)...
# Fetching KT (030200)...
# Fetching HD현대일렉트릭 (267260)...
# Fetching 우리금융지주 (316140)...
# Fetching SK텔레콤 (017670)...
# Fetching KT&G (033780)...
# Fetching 현대로템 (064350)...
# Fetching 에코프로비엠 (247540)...
# Fetching 카카오뱅크 (323410)...
# Fetching 포스코퓨처엠 (003670)...
# Fetching LG (003550)...
# Fetching 삼성전기 (009150)...
# Fetching 유한양행 (000100)...
# Fetching SK (034730)...
# Fetching 포스코인터내셔널 (047050)...
# Fetching 하이브 (352820)...
# Fetching HLB (028300)...
# Fetching 삼성에스디에스 (018260)...
# Fetching 현대글로비스 (086280)...
# Fetching 한미반도체 (042700)...
# Fetching 대한항공 (003490)...
# Fetching 한국항공우주 (047810)...
# Fetching SK바이오팜 (326030)...
# Fetching 에코프로 (086520)...
# Fetching 삼양식품 (003230)...
# Fetching DB손해보험 (005830)...
# Fetching S-Oil (010950)...
# Fetching 한화시스템 (272210)...
# Fetching 아모레퍼시픽 (090430)...
# Fetching HD현대마린솔루션 (443060)...
# Fetching LS ELECTRIC (010120)...
# Fetching 레인보우로보틱스 (277810)...
# Fetching LIG넥스원 (079550)...
# Fetching 코웨이 (021240)...
# Fetching HD현대 (267250)...
# Fetching 두산 (000150)...
# Fetching 미래에셋증권 (006800)...
# Fetching 한진칼 (180640)...
# Fetching 현대차2우B (005387)...
# Fetching 맥쿼리인프라 (088980)...
# Fetching SKC (011790)...
# Fetching LG생활건강 (051900)...
# Fetching LG씨엔에스 (064400)...
# Fetching 에코프로머티 (450080)...
# Fetching 한국타이어앤테크놀로지 (161390)...
# Fetching 두산밥캣 (241560)...
# Fetching 삼성카드 (029780)...
# Fetching NH투자증권 (005940)...
# Fetching LG유플러스 (032640)...
# Fetching LG디스플레이 (034220)...
# Fetching 삼천당제약 (000250)...
# Fetching 오리온 (271560)...
# Fetching 효성중공업 (298040)...
# Fetching 코오롱티슈진 (950160)...
# Fetching 포스코DX (022100)...
# Fetching LS (006260)...
# Fetching 휴젤 (145020)...
# Fetching HD현대미포 (010620)...
# Fetching 카카오페이 (377300)...
# Fetching 한국금융지주 (071050)...
# Fetching 삼성증권 (016360)...
# Fetching 두산로보틱스 (454910)...
# Fetching 클래시스 (214150)...
# Fetching 현대제철 (004020)...
# Fetching 리가켐바이오 (141080)...
# Fetching CJ제일제당 (097950)...
# Fetching 현대오토에버 (307950)...
# Fetching LG이노텍 (011070)...
# Fetching CJ (001040)...
# Fetching 삼성E&A (028050)...
# Fetching 현대건설 (000720)...
# Fetching 엔씨소프트 (036570)...
# Fetching 강원랜드 (035250)...
# Fetching 파마리서치 (214450)...
# Fetching 현대차우 (005385)...
# Fetching 한화솔루션 (009830)...
# Fetching 한화 (000880)...
# Fetching 넷마블 (251270)...
# Fetching GS (078930)...
# Fetching 한국가스공사 (036460)...
# Fetching SK바이오사이언스 (302440)...
# Fetching BNK금융지주 (138930)...
# Fetching 시프트업 (462870)...
# Fetching 리노공업 (058470)...
# Fetching JB금융지주 (175330)...
# Fetching 한화비전 (489790)...
# Fetching 롯데케미칼 (011170)...
# Fetching 한미약품 (128940)...
# Fetching 금호석유 (011780)...
# Fetching 키움증권 (039490)...
# Fetching 한온시스템 (018880)...
# Fetching 엘앤에프 (066970)...
# Fetching F&F (383220)...
# Fetching 동서 (026960)...
# Fetching 이수페타시스 (007660)...
# Fetching KCC (002380)...
# Fetching 에이피알 (278470)...
# Fetching 보로노이 (310210)...
# Fetching JYP Ent. (035900)...
# Fetching 한전기술 (052690)...
# Fetching 대한전선 (001440)...
# Fetching 롯데지주 (004990)...
# Fetching SK가스 (018670)...
# Fetching 이마트 (139480)...
# Fetching 에스원 (012750)...
# Fetching HPSP (403870)...
# Fetching 농심 (004370)...
# Fetching 한화생명 (088350)...
# Fetching 서울보증보험 (031210)...
# Fetching 셀트리온제약 (068760)...
# Fetching 아시아나항공 (020560)...
# Fetching 현대엘리베이 (017800)...
# Fetching 에스엠 (041510)...
# Fetching 휠라홀딩스 (081660)...
# Fetching 영원무역 (111770)...
# Fetching CJ대한통운 (000120)...
# Fetching 코스맥스 (192820)...
# Fetching 현대해상 (001450)...
# Fetching 펩트론 (087010)...
# Fetching 제일기획 (030000)...
# Fetching 더존비즈온 (012510)...
# Fetching 펄어비스 (263750)...
# Fetching DB하이텍 (000990)...
# Fetching 산일전기 (062040)...
# Fetching 한전KPS (051600)...
# Fetching 한화엔진 (082740)...
# Fetching 팬오션 (028670)...
# Fetching HL만도 (204320)...
# Fetching 신성델타테크 (065350)...
# Fetching 한미사이언스 (008930)...
# Fetching 롯데쇼핑 (023530)...
# Fetching SK아이이테크놀로지 (361610)...
# Fetching HD현대인프라코어 (042670)...
# Fetching 한올바이오파마 (009420)...
# Fetching 에이비엘바이오 (298380)...
# Fetching 풍산 (103140)...
# Fetching BGF리테일 (282330)...
# Fetching 엔켐 (348370)...
# Fetching 아모레G (002790)...
# Fetching DL이앤씨 (375500)...
# Fetching 이오테크닉스 (039030)...
# Fetching 이수스페셜티케미컬 (457190)...
# Fetching 실리콘투 (257720)...
# Fetching 솔브레인 (357780)...
# Fetching 주성엔지니어링 (036930)...
# Fetching 에스엘 (005850)...
# Fetching 루닛 (328130)...
# Fetching 오뚜기 (007310)...
# Fetching 동진쎄미켐 (005290)...
# Fetching 젬백스 (082270)...
# Fetching 코리안리 (003690)...
# Fetching 코스모신소재 (005070)...
# Fetching 한국콜마 (161890)...
# Fetching 한솔케미칼 (014680)...
# Fetching 씨에스윈드 (112610)...
# Fetching 호텔신라 (008770)...
# Fetching 대주전자재료 (078600)...
# Fetching 한국앤컴퍼니 (000240)...
# Fetching 에스티팜 (237690)...
# Fetching GS건설 (006360)...
# Fetching 녹십자 (006280)...
# Fetching OCI홀딩스 (010060)...
# Fetching DGB금융지주 (139130)...
# Fetching 신세계 (004170)...
# Fetching 대우건설 (047040)...
# Fetching 동원산업 (006040)...
# Fetching 케어젠 (214370)...
# Fetching 파크시스템스 (140860)...
# Fetching 금호타이어 (073240)...
# Fetching 스튜디오드래곤 (253450)...
# Fetching 대웅제약 (069620)...
# Fetching SK리츠 (395400)...
# Fetching 하이트진로 (000080)...
# Fetching 카페24 (042000)...
# Fetching HDC현대산업개발 (294870)...
# Fetching HD현대건설기계 (267270)...
# Fetching 현대백화점 (069960)...
# Fetching 일진전기 (103590)...
# Fetching 테크윙 (089030)...
# Fetching 신영증권 (001720)...
# Fetching ISC (095340)...
# Fetching 카카오게임즈 (293490)...
# Fetching 씨젠 (096530)...
# Fetching 영원무역홀딩스 (009970)...
# Fetching 원익IPS (240810)...
# Fetching 브이티 (018290)...
# Fetching 서진시스템 (178320)...
# Fetching GS리테일 (007070)...
# Fetching 에스디바이오센서 (137310)...
# Fetching CJ ENM (035760)...
# Fetching 오스코텍 (039200)...
# Fetching 현대위아 (011210)...
# Fetching DN오토모티브 (007340)...
# Fetching 롯데에너지머티리얼즈 (020150)...
# Fetching 고영 (098460)...
# Fetching 경동나비엔 (009450)...
# Fetching SNT다이내믹스 (003570)...
# Fetching 하이젠알앤엠 (160190)...
# Fetching 와이지엔터테인먼트 (122870)...
# Fetching 한일시멘트 (300720)...
# Fetching 대웅 (003090)...
# Fetching LS에코에너지 (229640)...
# Fetching 롯데웰푸드 (280360)...
# Fetching 세아제강지주 (003030)...
# Fetching 종근당 (185750)...
# Fetching HLB생명과학 (067630)...
# Fetching 롯데렌탈 (089860)...
# Fetching 제이앤티씨 (204270)...
# Fetching 더블유게임즈 (192080)...
# Fetching 티씨케이 (064760)...
# Fetching 위메이드 (112040)...
# Fetching 롯데정밀화학 (004000)...
# Fetching 두산퓨얼셀 (336260)...
# Fetching 피엔티 (137400)...
# Fetching 레이크머티리얼즈 (281740)...
# Fetching HK이노엔 (195940)...
# Fetching 동원시스템즈 (014820)...
# Fetching 한샘 (009240)...
# Fetching ESR켄달스퀘어리츠 (365550)...
# Fetching 네이처셀 (007390)...
# Fetching 효성티앤씨 (298020)...
# Fetching 필옵틱스 (161580)...
# Fetching 롯데리츠 (330590)...
# Fetching 롯데칠성 (005300)...
# Fetching LX인터내셔널 (001120)...
# Fetching 세방전지 (004490)...
# Fetching 유진테크 (084370)...
# Fetching SOOP (067160)...
# Fetching 다우기술 (023590)...
# Fetching HD현대마린엔진 (071970)...
# Fetching 메디톡스 (086900)...
# Fetching SK네트웍스 (001740)...
# Fetching 오리온홀딩스 (001800)...
# Fetching 파라다이스 (034230)...
# Fetching LX세미콘 (108320)...
# Fetching 빙그레 (005180)...
# Fetching 올릭스 (226950)...
# Fetching 삼성화재우 (000815)...
# Fetching 태성 (323280)...
# Fetching 디어유 (376300)...
# Fetching KB발해인프라 (415640)...
# Fetching 국일제지 (078130)...
# Fetching 하나투어 (039130)...
# Fetching 대덕전자 (353200)...
# Fetching 영풍 (000670)...
# Fetching 가온전선 (000500)...
# Fetching 솔루엠 (248070)...
# Fetching DI동일 (001530)...
# Fetching SK오션플랜트 (100090)...
# Fetching 코오롱인더 (120110)...
# Fetching HDC (012630)...
# Fetching 피에스케이홀딩스 (031980)...
# Fetching LG화학우 (051915)...
# Fetching 미원상사 (002840)...
# Fetching 대신증권 (003540)...
# Fetching 금양 (001570)...
# Fetching 나노신소재 (121600)...
# Fetching 와이씨 (232140)...
# Fetching 대상 (001680)...
# Fetching 보령 (003850)...
# Fetching 태광산업 (003240)...
# Fetching 프레스티지바이오파마 (950210)...
# Fetching 메지온 (140410)...
# Fetching HS효성첨단소재 (298050)...
# Fetching 현대지에프홀딩스 (005440)...
# Fetching 안랩 (053800)...
# Fetching CJ CGV (079160)...
# Fetching 한국카본 (017960)...
# Fetching LS머트리얼즈 (417200)...
# Fetching 넥슨게임즈 (225570)...
# Fetching 전진건설로봇 (079900)...
# Fetching 쿠쿠홀딩스 (192400)...
# Fetching 동양생명 (082640)...
# Fetching 미래에셋생명 (085620)...
# Fetching 효성 (004800)...
# Fetching HLB제약 (047920)...
# Fetching 케이씨텍 (281820)...
# Fetching 유일로보틱스 (388720)...
# Fetching 하나마이크론 (067310)...
# Fetching 교보증권 (030610)...
# Fetching KG모빌리티 (003620)...
# Fetching 성광벤드 (014620)...
# Fetching SK디스커버리 (006120)...
# Fetching 이노션 (214320)...
# Fetching 동성화인텍 (033500)...
# Fetching 파미셀 (005690)...
# Fetching 미원에스씨 (268280)...
# Fetching 한화투자증권 (003530)...
# Fetching NICE평가정보 (030190)...
# Fetching 한국단자 (025540)...
# Fetching DL (000210)...
# Fetching 코스모화학 (005420)...
# Fetching SK케미칼 (285130)...
# Fetching 엠앤씨솔루션 (484870)...
# Fetching 에스앤에스텍 (101490)...
# Fetching 세아베스틸지주 (001430)...
# Fetching TCC스틸 (002710)...
# Fetching 신한알파리츠 (293940)...
# Fetching 덕산네오룩스 (213420)...
# Fetching 태영건설 (009410)...
# Fetching 에스에프에이 (056190)...
# Fetching SNT에너지 (100840)...
# Fetching 하나머티리얼즈 (166090)...
# Fetching 파두 (440110)...
# Fetching 지아이이노베이션 (358570)...
# Fetching 덴티움 (145720)...
# Fetching 동국제약 (086450)...
# Fetching KG스틸 (016380)...
# Fetching HLB테라퓨틱스 (115450)...
# Fetching 심텍 (222800)...
# Fetching LG전자우 (066575)...
# Fetching 솔브레인홀딩스 (036830)...
# Fetching GKL (114090)...
# Fetching SNT모티브 (064960)...
# Fetching 차바이오텍 (085660)...
# Fetching HJ중공업 (097230)...
# Fetching 엠로 (058970)...
# Fetching 위메이드맥스 (101730)...
# Fetching 한화리츠 (451800)...
# Fetching 풀무원 (017810)...
# Fetching 녹십자홀딩스 (005250)...
# Fetching TKG휴켐스 (069260)...
# Fetching 솔루스첨단소재 (336370)...
# Fetching 동원F&B (049770)...
# Fetching 율촌화학 (008730)...
# Fetching 대한유화 (006650)...
# Fetching 비에이치아이 (083650)...
# Fetching 태광 (023160)...
# Fetching 동아쏘시오홀딩스 (000640)...
# Fetching 오름테라퓨틱 (475830)...
# Fetching 케이카 (381970)...
# Fetching 티앤엘 (340570)...
# Fetching 카프로 (006380)...
# Fetching 씨아이에스 (222080)...
# Fetching 제룡전기 (033100)...
# Fetching 현대홈쇼핑 (057050)...
# Fetching NHN (181710)...
# Fetching 쎄트렉아이 (099320)...
# Fetching 두산우 (000155)...
# Fetching 비츠로셀 (082920)...
# Fetching 시노펙스 (025320)...
# Fetching 넥스틴 (348210)...
# Fetching 롯데관광개발 (032350)...
# Fetching 에코프로에이치엔 (383310)...
# Fetching 포스코엠텍 (009520)...
# Fetching 펌텍코리아 (251970)...
# Fetching STX엔진 (077970)...
# Fetching 원텍 (336570)...
# Fetching 두산테스나 (131970)...
# Fetching 미래에셋증권2우B (00680K)...
# Fetching 하림지주 (003380)...
# Fetching 코미코 (183300)...
# Fetching 세아제강 (306200)...
# Fetching 컴투스 (078340)...
# Fetching 에스피지 (058610)...
# Fetching 현대힘스 (460930)...
# Fetching 가온칩스 (399720)...
# Fetching 제주항공 (089590)...
# Fetching 롯데손해보험 (000400)...
# Fetching 지역난방공사 (071320)...
# Fetching 현대바이오 (048410)...
# Fetching 아세아 (002030)...
# Fetching 티에스이 (131290)...
# Fetching 피에스케이 (319660)...
# Fetching 유안타증권 (003470)...
# Fetching 대한해운 (005880)...
# Fetching 퓨쳐켐 (220100)...
# Fetching 쏘카 (403550)...
# Fetching 휴온스글로벌 (084110)...
# Fetching LS마린솔루션 (060370)...
# Fetching 디앤디파마텍 (347850)...
# Fetching 바이넥스 (053030)...
# Fetching 제주반도체 (080220)...
# Fetching 클로봇 (466100)...
# Fetching 원익QnC (074600)...
# Fetching 유니드 (014830)...
# Fetching 우리기술투자 (041190)...
# Fetching PI첨단소재 (178920)...
# Fetching 일진하이솔루스 (271940)...
# Fetching 넥센타이어 (002350)...
# Fetching OCI (456040)...
# Fetching SNT홀딩스 (036530)...
# Fetching 해성디에스 (195870)...
# Fetching 덕산테코피아 (317330)...
# Fetching 아난티 (025980)...
# Fetching 삼양홀딩스 (000070)...
# Fetching JW중외제약 (001060)...
# Fetching SFA반도체 (036540)...
# Fetching 티웨이항공 (091810)...
# Fetching 제이알글로벌리츠 (348950)...
# Fetching 이녹스첨단소재 (272290)...
# Fetching 비에이치 (090460)...
# Fetching 동화기업 (025900)...
# Fetching LX홀딩스 (383800)...
# Fetching SK이터닉스 (475150)...
# Fetching 진에어 (272450)...
# Fetching KCC글라스 (344820)...
# Fetching 아이에스동서 (010780)...
# Fetching 엘앤씨바이오 (290650)...
# Fetching 화승엔터프라이즈 (241590)...
# Fetching 제우스 (079370)...
# Fetching 에스티큐브 (052020)...
# Fetching 에코앤드림 (101360)...
# Fetching 바이오노트 (377740)...
# Fetching 로보티즈 (108490)...
# Fetching F&F홀딩스 (007700)...
# Fetching 후성 (093370)...
# Fetching 한글과컴퓨터 (030520)...
# Fetching 퍼시스 (016800)...
# Fetching 드림텍 (192650)...
# Fetching 네오셈 (253590)...
# Fetching 쿠쿠홈시스 (284740)...
# Fetching 한세실업 (105630)...
# Fetching 고려제강 (002240)...
# Fetching 동국제강 (460860)...
# Fetching 한화손해보험 (000370)...
# Fetching 켐트로닉스 (089010)...
# Fetching 코스메카코리아 (241710)...
# Fetching 비올 (335890)...
# Fetching 테스 (095610)...
# Fetching 명신산업 (009900)...
# Fetching 남양유업 (003920)...
# Fetching 에프에스티 (036810)...
# Fetching 삼양사 (145990)...
# Fetching DS단석 (017860)...
# Fetching 코오롱생명과학 (102940)...
# Fetching SPC삼립 (005610)...
# Fetching 네오위즈 (095660)...
# Fetching 지노믹트리 (228760)...
# Fetching 동신건설 (025950)...
# Fetching 현대그린푸드 (453340)...
# Fetching 인텔리안테크 (189300)...
# Fetching 중앙첨단소재 (051980)...
# Fetching 웹젠 (069080)...
# Fetching LF (093050)...
# Fetching 선익시스템 (171090)...
# Fetching 엠씨넥스 (097520)...
# Fetching 유티아이 (179900)...
# Fetching 휴메딕스 (200670)...
# Fetching 세진중공업 (075580)...
# Fetching 씨앤씨인터내셔널 (352480)...
# Fetching 넥스틸 (092790)...
# Fetching 한일홀딩스 (003300)...
# Fetching 삼아알미늄 (006110)...
# Fetching 유바이오로직스 (206650)...
# Fetching 엔젤로보틱스 (455900)...
# Fetching 바이오플러스 (099430)...
# Fetching 코엔텍 (029960)...
# Fetching 아이센스 (099190)...
# Fetching 신풍제약 (019170)...
# Fetching 쏠리드 (050890)...
# Fetching 동운아나텍 (094170)...
# Fetching 대상홀딩스 (084690)...
# Fetching 코람코라이프인프라리츠 (357120)...
# Fetching 더본코리아 (475560)...
# Fetching 동아에스티 (170900)...
# Fetching 성우하이텍 (015750)...
# Fetching 성일하이텍 (365340)...
# Fetching E1 (017940)...
# Fetching RFHIC (218410)...
# Fetching 대신증권우 (003545)...
# Fetching 삼성FN리츠 (448730)...
# Fetching 현대무벡스 (319400)...
# Fetching 다우데이타 (032190)...
# Fetching NICE (034310)...
# Fetching 큐로셀 (372320)...
# Fetching 피아이이 (452450)...
# Fetching CJ4우(전환) (00104K)...
# Fetching 흥아해운 (003280)...
# Fetching 코나아이 (052400)...
# Fetching 한국기업평가 (034950)...
# Fetching 풍산홀딩스 (005810)...
# Fetching 메가스터디교육 (215200)...
# Fetching 아이쓰리시스템 (214430)...
# Fetching 삼현 (437730)...
# Fetching 데브시스터즈 (194480)...
# Fetching 클리오 (237880)...
# Fetching 한국쉘석유 (002960)...
# Fetching 지누스 (013890)...
# Fetching 맵스리얼티1 (094800)...
# Fetching GST (083450)...
# Fetching 파트론 (091700)...
# Fetching 바이오니아 (064550)...
# Fetching 필에너지 (378340)...
# Fetching SBS (034120)...
# Fetching 바이오다인 (314930)...
# Fetching 큐렉소 (060280)...
# Fetching 아세아시멘트 (183190)...
# Fetching 서울반도체 (046890)...
# Fetching 신도리코 (029530)...
# Fetching 다원시스 (068240)...
# Fetching 에이프릴바이오 (397030)...
# Fetching 골프존 (215000)...
# Fetching 세아홀딩스 (058650)...
# Fetching 대한제강 (084010)...
# Fetching GS피앤엘 (499790)...
# Fetching 애경산업 (018250)...
# Fetching 기가비스 (420770)...
# Fetching KB스타리츠 (432320)...
# Fetching 칩스앤미디어 (094360)...
# Fetching 현대퓨처넷 (126560)...
# Fetching 한화3우B (00088K)...
# Fetching 원익홀딩스 (030530)...
# Fetching 콜마비앤에이치 (200130)...
# Fetching 디아이 (003160)...
# Fetching 사조대림 (003960)...
# Fetching 넥스트바이오메디컬 (389650)...
# Fetching 신세계인터내셔날 (031430)...
# Fetching 하이록코리아 (013030)...
# Fetching 엔솔바이오사이언스 (140610)...
# Fetching 천보 (278280)...
# Fetching 케이아이엔엑스 (093320)...
# Fetching 영진약품 (003520)...
# Fetching 삼천리 (004690)...
# Fetching 에이직랜드 (445090)...
# Fetching 아이패밀리에스씨 (114840)...
# Fetching 아모레퍼시픽우 (090435)...
# Fetching 지씨셀 (144510)...
# Fetching 씨메스 (475400)...
# Fetching 한전산업 (130660)...
# Fetching 이엔에프테크놀로지 (102710)...
# Fetching 서부T&D (006730)...
# Fetching 제이오 (418550)...
# Fetching HLB이노베이션 (024850)...
# Fetching 한섬 (020000)...
# Fetching 이아이디 (093230)...
# Fetching 넵튠 (217270)...
# Fetching 셀바스AI (108860)...
# Fetching 애경케미칼 (161000)...
# Fetching HL홀딩스 (060980)...
# Fetching 듀켐바이오 (176750)...
# Fetching 현대차3우B (005389)...
# Fetching 바디텍메드 (206640)...
# Fetching 서희건설 (035890)...
# Fetching 서연이화 (200880)...
# Fetching 조광피혁 (004700)...
# Fetching 비보존 제약 (082800)...
# Fetching 휴스틸 (005010)...
# Fetching 삼표시멘트 (038500)...
# Fetching 브릿지바이오테라퓨틱스 (288330)...
# Fetching 신라젠 (215600)...
# Fetching LS네트웍스 (000680)...
# Fetching SGC에너지 (005090)...
# Fetching 우리기술 (032820)...
# Fetching 에스티아이 (039440)...
# Fetching 미코 (059090)...
# Fetching 아스테라시스 (450950)...
# Fetching 인터로조 (119610)...
# Fetching 프레스티지바이오로직스 (334970)...
# Fetching 뉴로메카 (348340)...
# Fetching 신성에스티 (416180)...
# Fetching 하림 (136480)...
# Fetching YG PLUS (037270)...
# Fetching BGF (027410)...
# Fetching NHN KCP (060250)...
# Fetching 갤럭시아머니트리 (094480)...
# Fetching 뷰노 (338220)...
# Fetching 한국금융지주우 (071055)...
# Fetching 현대코퍼레이션 (011760)...
# Fetching 인바디 (041830)...
# Fetching 휴온스 (243070)...
# Fetching 감성코퍼레이션 (036620)...
# Fetching 월덱스 (101160)...
# Fetching 태웅 (044490)...
# Fetching 남해화학 (025860)...
# Fetching 일동제약 (249420)...
# Fetching 부광약품 (003000)...
# Fetching 대원제약 (003220)...
# Fetching 코오롱 (002020)...
# Fetching 마녀공장 (439090)...
# Fetching 유진로봇 (056080)...
# Fetching 신성통상 (005390)...
# Fetching 대동 (000490)...
# Fetching 유나이티드제약 (033270)...
# Fetching 백광산업 (001340)...
# Fetching 백산 (035150)...
# Fetching 아세아제지 (002310)...
# Fetching 오픈엣지테크놀로지 (394280)...
# Fetching 바텍 (043150)...
# Fetching 인카금융서비스 (211050)...
# Fetching 한국자산신탁 (123890)...
# Fetching 인탑스 (049070)...
# Fetching 글로벌텍스프리 (204620)...
# Fetching 농심홀딩스 (072710)...
# Fetching 한양이엔지 (045100)...
# Fetching 에스바이오메딕스 (304360)...
# Fetching 메디포스트 (078160)...
# Fetching 솔트룩스 (304100)...
# Fetching 케이엠더블유 (032500)...
# Fetching 에치에프알 (230240)...
# Fetching 수산인더스트리 (126720)...
# Fetching 윤성에프앤씨 (372170)...
# Fetching 더블유씨피 (393890)...
# Fetching 삼목에스폼 (018310)...
# Fetching 스틱인베스트먼트 (026890)...
# Fetching 롯데이노베이트 (286940)...
# Fetching 인화정공 (101930)...
# Fetching 자화전자 (033240)...
# Fetching 코미팜 (041960)...
# Fetching 교촌에프앤비 (339770)...
# Fetching 한국철강 (104700)...
# Fetching 삼화콘덴서 (001820)...
# Fetching 폴라리스오피스 (041020)...
# Fetching 엘브이엠씨홀딩스 (900140)...
# Fetching GRT (900290)...
# Fetching HD현대에너지솔루션 (322000)...
# Fetching 토비스 (051360)...
# Fetching 한진 (002320)...
# Fetching 광동제약 (009290)...
# Fetching 한국정보통신 (025770)...
# Fetching 예스코홀딩스 (015360)...
# Fetching 한일현대시멘트 (006390)...
# Fetching 송원산업 (004430)...
# Fetching 티로보틱스 (117730)...
# Fetching 에이치브이엠 (295310)...
# Fetching 화승인더 (006060)...
# Fetching 세경하이테크 (148150)...
# Fetching 에코마케팅 (230360)...
# Fetching 성우 (458650)...
# Fetching 코리아써키트 (007810)...
# Fetching 디앤디플랫폼리츠 (377190)...
# Fetching 이엠텍 (091120)...
# Fetching 에스에이엠티 (031330)...
# Fetching KISCO홀딩스 (001940)...
# Fetching 풍원정밀 (371950)...
# Fetching 엣지파운드리 (105550)...
# Fetching 아이티엠반도체 (084850)...
# Fetching 한농화성 (011500)...
# Fetching 디아이티 (110990)...
# Fetching 부국증권 (001270)...
# Fetching 에이스침대 (003800)...
# Fetching 한국비엔씨 (256840)...
# Fetching 지엔씨에너지 (119850)...
# Fetching 석경에이티 (357550)...
# Fetching 샘씨엔에스 (252990)...
# Fetching 대화제약 (067080)...
# Fetching 국도화학 (007690)...
# Fetching 에이텍 (045660)...
# Fetching 툴젠 (199800)...
# Fetching AP시스템 (265520)...
# Fetching 제이브이엠 (054950)...
# Fetching 매일유업 (267980)...
# Fetching 이리츠코크렙 (088260)...
# Fetching LX하우시스 (108670)...
# Fetching 우주일렉트로 (065680)...
# Fetching 엑스게이트 (356680)...
# Fetching 예스티 (122640)...
# Fetching 삼일제약 (000520)...
# Fetching LG생활건강우 (051905)...
# Fetching 원익머트리얼즈 (104830)...
# Fetching KG케미칼 (001390)...
# Fetching 프로텍 (053610)...
# Fetching 포스코스틸리온 (058430)...
# Fetching JTC (950170)...
# Fetching 신대양제지 (016590)...
# Fetching 셀비온 (308430)...
# Fetching 로체시스템즈 (071280)...
# Fetching 아스트 (067390)...
# Fetching 모토닉 (009680)...
# Fetching 아주IB투자 (027360)...
# Fetching 아이마켓코리아 (122900)...
# Fetching 화신 (010690)...
# Fetching 파이버프로 (368770)...
# Fetching 하이비젼시스템 (126700)...
# Fetching 펨트론 (168360)...
# Fetching 슈어소프트테크 (298830)...
# Fetching 코난테크놀로지 (402030)...
# Fetching 유진기업 (023410)...
# Fetching 미래나노텍 (095500)...
# Fetching SIMPAC (009160)...
# Fetching 비덴트 (121800)...
# Fetching 에어부산 (298690)...
# Fetching 와이씨켐 (112290)...
# Fetching CMG제약 (058820)...
# Fetching DB (012030)...
# Fetching 오리엔트정공 (065500)...
# Fetching KG에코솔루션 (151860)...
# Fetching 자람테크놀로지 (389020)...
# Fetching 미래에셋벤처투자 (100790)...
# Fetching SG (255220)...
# Fetching 신성이엔지 (011930)...
# Fetching 한국토지신탁 (034830)...
# Fetching 삼화전기 (009470)...
# Fetching 인트로메딕 (150840)...
# Fetching 상아프론테크 (089980)...
# Fetching DB금융투자 (016610)...
# Fetching 케이씨 (029460)...
# Fetching 삼영무역 (002810)...
# Fetching 제주은행 (006220)...
# Fetching 엠아이텍 (179290)...
# Fetching CR홀딩스 (000480)...
# Fetching 유진투자증권 (001200)...
# Fetching 탑머티리얼 (360070)...
# Fetching SAMG엔터 (419530)...
# Fetching 유니테스트 (086390)...
# Fetching 잇츠한불 (226320)...
# Fetching 제테마 (216080)...
# Fetching 로보스타 (090360)...
# Fetching 서울가스 (017390)...
# Fetching 큐리옥스바이오시스템즈 (445680)...
# Fetching 삼진제약 (005500)...
# Fetching 이트론 (096040)...
# Fetching 넥센 (005720)...
# Fetching NH투자증권우 (005945)...
# Fetching 콜마홀딩스 (024720)...
# Fetching 대한제당 (001790)...
# Fetching 동국홀딩스 (001230)...
# Fetching 아바코 (083930)...
# Fetching 에이디테크놀로지 (200710)...
# Fetching 대덕 (008060)...
# Fetching 휴림로봇 (090710)...
# Fetching 한솔아이원스 (114810)...
# Fetching CJ프레시웨이 (051500)...
# Fetching KG이니시스 (035600)...
# Fetching 모트렉스 (118990)...
# Fetching 오리엔탈정공 (014940)...
# Fetching 삼익THK (004380)...
# Fetching 한화갤러리아 (452260)...
# Fetching 큐리언트 (115180)...
# Fetching 디오 (039840)...
# Fetching KPX홀딩스 (092230)...
# Fetching 아나패스 (123860)...
# Fetching 파멥신 (208340)...
# Fetching 에이프로젠 (007460)...
# Fetching 광주신세계 (037710)...
# Fetching 브이엠 (089970)...
# Fetching 인선이엔티 (060150)...
# Fetching 대원전선 (006340)...
# Fetching 코오롱ENP (138490)...
# Fetching 세방 (004360)...
# Fetching 동국산업 (005160)...
# Fetching 제이에스코퍼레이션 (194370)...
# Fetching 퀄리타스반도체 (432720)...
# Fetching 오로스테크놀로지 (322310)...
# Fetching 대아티아이 (045390)...
# Fetching 큐브엔터 (182360)...
# Fetching 텔레칩스 (054450)...
# Fetching 이지스밸류리츠 (334890)...
# Fetching 제일일렉트릭 (199820)...
# Fetching 대원강업 (000430)...
# Fetching HDC랩스 (039570)...
# Fetching 피에이치에이 (043370)...
# Fetching 도화엔지니어링 (002150)...
# Fetching 진성티이씨 (036890)...
# Fetching 한국화장품제조 (003350)...
# Fetching HB테크놀러지 (078150)...
# Fetching 한중엔시에스 (107640)...
# Fetching KH바텍 (060720)...
# Fetching JW홀딩스 (096760)...
# Fetching 티에프이 (425420)...
# Fetching 시너지이노베이션 (048870)...
# Fetching 디앤씨미디어 (263720)...
# Fetching 어보브반도체 (102120)...
# Fetching SK증권 (001510)...
# Fetching 뷰웍스 (100120)...
# Fetching 이스트소프트 (047560)...
# Fetching TYM (002900)...
# Fetching 이연제약 (102460)...
# Fetching 대한제분 (001130)...
# Fetching 인터플렉스 (051370)...
# Fetching LB세미콘 (061970)...
# Fetching 노머스 (473980)...
# Fetching 동방메디컬 (240550)...
# Fetching 삼양패키징 (272550)...
# Fetching 앱클론 (174900)...
# Fetching 주성코퍼레이션 (109070)...
# Fetching 종근당홀딩스 (001630)...
# Fetching 대성에너지 (117580)...
# Fetching 푸른소나무 (057880)...
# Fetching GS글로벌 (001250)...
# Fetching 에스앤디 (260970)...
# Fetching 뉴파워프라즈마 (144960)...
# Fetching 환인제약 (016580)...
# Fetching 알루코 (001780)...
# Fetching 토니모리 (214420)...
# Fetching 동국씨엠 (460850)...
# Fetching KPX케미칼 (025000)...
# Fetching 위지윅스튜디오 (299900)...
# Fetching LS증권 (078020)...
# Fetching 동원개발 (013120)...
# Fetching 유니셈 (036200)...
# Fetching 해성산업 (034810)...
# Fetching 에스오에스랩 (464080)...
# Fetching 비츠로테크 (042370)...
# Fetching 흥국화재 (000540)...
# Fetching 조일알미늄 (018470)...
# Fetching 대명에너지 (389260)...
# Fetching 박셀바이오 (323990)...
# Fetching 스카이라이프 (053210)...
# Fetching 휴마시스 (205470)...
# Fetching 리파인 (377450)...
# Fetching 일양약품 (007570)...
# Fetching 소룩스 (290690)...
# Fetching HB솔루션 (297890)...
# Fetching 일성건설 (013360)...
# Fetching 삼성SDI우 (006405)...
# Fetching 강원에너지 (114190)...
# Fetching 한솔제지 (213500)...
# Fetching 토모큐브 (475960)...
# Fetching 일성아이에스 (003120)...
# Fetching 가비아 (079940)...
# Fetching 에코아이 (448280)...
# Fetching 바이오솔루션 (086820)...
# Fetching 오상헬스케어 (036220)...
# Fetching 엘케이켐 (489500)...
# Fetching 파인엠텍 (441270)...
# Fetching KSS해운 (044450)...
# Fetching 슈프리마 (236200)...
# Fetching 압타바이오 (293780)...
# Fetching 디지털대성 (068930)...
# Fetching 현대비앤지스틸 (004560)...
# Fetching 삼영전자 (005680)...
# Fetching 제이엘케이 (322510)...
# Fetching 다날 (064260)...
# Fetching 대동기어 (008830)...
# Fetching 쿠콘 (294570)...
# Fetching 에브리봇 (270660)...
# Fetching 하이트진로홀딩스 (000140)...
# Fetching 삼양엔씨켐 (482630)...
# Fetching 안트로젠 (065660)...
# Fetching 코람코더원리츠 (417310)...
# Fetching 현대차증권 (001500)...
# Fetching 미래컴퍼니 (049950)...
# Fetching 이화전기 (024810)...
# Fetching AP위성 (211270)...
# Fetching 대진첨단소재 (393970)...
# Fetching 영풍정밀 (036560)...
# Fetching HLB글로벌 (003580)...
# Fetching 케이프 (064820)...
# Fetching 폴라리스AI (039980)...
# Fetching 아미코젠 (092040)...
# Fetching 엑세스바이오 (950130)...
# Fetching 티엘비 (356860)...
# Fetching 에스피소프트 (443670)...
# Fetching 모나용평 (070960)...
# Fetching 한국알콜 (017890)...
# Fetching 이수앱지스 (086890)...
# Fetching 나무가 (190510)...
# Fetching 에스와이 (109610)...
# Fetching 멀티캠퍼스 (067280)...
# Fetching 제닉 (123330)...
# Fetching 동성케미컬 (102260)...
# Fetching 쇼박스 (086980)...
# Fetching 한국정보인증 (053300)...
# Fetching 신세계 I&C (035510)...
# Fetching 덕산하이메탈 (077360)...
# Fetching 무학 (033920)...
# Fetching 그래디언트 (035080)...
# Fetching 네오팜 (092730)...
# Fetching 알멕 (354320)...
# Fetching 브랜드엑스코퍼레이션 (337930)...
# Fetching 이노스페이스 (462350)...
# Fetching HLB바이오스텝 (278650)...
# Fetching 현대사료 (016790)...
# Fetching 이월드 (084680)...
# Fetching 에이블씨엔씨 (078520)...
# Fetching 노루홀딩스 (000320)...
# Fetching 에스와이스틸텍 (365330)...
# Fetching 폰드그룹 (472850)...
# Fetching 모다이노칩 (080420)...
# Fetching 제넥신 (095700)...
# Fetching 신흥에스이씨 (243840)...
# Fetching 다올투자증권 (030210)...
# Fetching 하나제약 (293480)...
# Fetching LG헬로비전 (037560)...
# Fetching 대교 (019680)...
# Fetching 한미글로벌 (053690)...
# Fetching 모두투어 (080160)...
# Fetching 케이티알파 (036030)...
# Fetching 사람인 (143240)...
# Fetching 엠케이전자 (033160)...
# Fetching 이엔셀 (456070)...
# Fetching 일신방직 (003200)...
# Fetching 서연 (007860)...
# Fetching 유비쿼스홀딩스 (078070)...
# Fetching 퍼스텍 (010820)...
# Fetching 켄코아에어로스페이스 (274090)...
# Fetching 무림P&P (009580)...
# Fetching 스마트레이더시스템 (424960)...
# Fetching 탑런토탈솔루션 (336680)...
# Fetching 이지홀딩스 (035810)...
# Fetching 대봉엘에스 (078140)...
# Fetching CG인바이츠 (083790)...
# Fetching 성신양회 (004980)...
# Fetching 경방 (000050)...
# Fetching 하나기술 (299030)...
# Fetching 일진홀딩스 (015860)...
# Fetching 동아지질 (028100)...
# Fetching 랩지노믹스 (084650)...
# Fetching 와이솔 (122990)...
# Fetching JW생명과학 (234080)...
# Fetching 디아이씨 (092200)...
# Fetching 엘오티베큠 (083310)...
# Fetching 와이지-원 (019210)...
# Fetching 오리엔트바이오 (002630)...
# Fetching 아가방컴퍼니 (013990)...
# Fetching 웅진씽크빅 (095720)...
# Fetching 쓰리빌리언 (394800)...
# Fetching 롯데하이마트 (071840)...
# Fetching 경농 (002100)...
# Fetching 유비케어 (032620)...
# Fetching CJ제일제당 우 (097955)...
# Fetching 해태제과식품 (101530)...
# Fetching 루미르 (474170)...
# Fetching 에이비온 (203400)...
# Fetching 한국전자금융 (063570)...
# Fetching 대양전기공업 (108380)...
# Fetching 삼성전기우 (009155)...
# Fetching 미래반도체 (254490)...
# Fetching 남선알미늄 (008350)...
# Fetching 파워로직스 (047310)...
# Fetching 서흥 (008490)...
# Fetching 와이엠티 (251370)...
# Fetching 아이씨티케이 (456010)...
# Fetching 씨어스테크놀로지 (458870)...
# Fetching 신한서부티엔디리츠 (404990)...
# Fetching 나이스정보통신 (036800)...
# Fetching 경동제약 (011040)...
# Fetching 에이럭스 (475580)...
# Fetching 와이팜 (332570)...
# Fetching BGF에코머티리얼즈 (126600)...
# Fetching 엠에스오토텍 (123040)...
# Fetching 한국캐피탈 (023760)...
# Fetching 씨티씨바이오 (060590)...
# Fetching 아이스크림미디어 (461300)...
# Fetching AJ네트웍스 (095570)...
# Fetching 우진엔텍 (457550)...
# Fetching 케이엔솔 (053080)...
# Fetching 엔케이맥스 (182400)...
# Fetching 동화약품 (000020)...
# Fetching 미창석유 (003650)...
# Fetching 라이프시맨틱스 (347700)...
# Fetching 코오롱글로벌 (003070)...
# Fetching LG우 (003555)...
# Fetching 미원화학 (134380)...
# Fetching 넥써쓰 (205500)...
# Fetching 골프존뉴딘홀딩스 (121440)...
# Fetching 조선내화 (462520)...
# Fetching 한양디지텍 (078350)...
# Fetching 톱텍 (108230)...
# Fetching 마크로젠 (038290)...
# Fetching 크레버스 (096240)...
# Fetching 케이에스피 (073010)...
# Fetching BYC (001460)...
# Fetching 진양홀딩스 (100250)...
# Fetching 삼화페인트 (000390)...
# Fetching 사조산업 (007160)...
# Fetching 한국파마 (032300)...
# Fetching 코오롱모빌리티그룹 (450140)...
# Fetching 미원홀딩스 (107590)...
# Fetching 나스미디어 (089600)...
# Fetching 마이크로디지탈 (305090)...
# Fetching 드림시큐리티 (203650)...
# Fetching 하이텍팜 (106190)...
# Fetching 인스코비 (006490)...
# Fetching 네패스 (033640)...
# Fetching 흥구석유 (024060)...
# Fetching 진원생명과학 (011000)...
# Fetching 컨텍 (451760)...
# Fetching KX (122450)...
# Fetching 아주스틸 (139990)...
# Fetching 코윈테크 (282880)...
# Fetching 한빛레이저 (452190)...
# Fetching 이구산업 (025820)...
# Fetching 레드캡투어 (038390)...
# Fetching 덱스터 (206560)...
# Fetching 현대에버다임 (041440)...
# Fetching 아이디스 (143160)...
# Fetching 노바텍 (285490)...
# Fetching 이지바이오 (353810)...
# Fetching 노바렉스 (194700)...
# Fetching 헥토이노베이션 (214180)...
# Fetching 한세예스24홀딩스 (016450)...
# Fetching 국전약품 (307750)...
# Fetching 한국공항 (005430)...
# Fetching 엑시콘 (092870)...
# Fetching 동국생명과학 (303810)...
# Fetching 매커스 (093520)...
# Fetching 앱트뉴로사이언스 (270520)...
# Fetching 양지사 (030960)...
# Fetching 콘텐트리중앙 (036420)...
# Fetching 원준 (382840)...
# Fetching 한국석유 (004090)...
# Fetching 일진다이아 (081000)...
# Fetching 큐알티 (405100)...
# Fetching DH오토넥스 (000300)...
# Fetching 케이피에스 (256940)...
# Fetching 동양이엔피 (079960)...
# Fetching KG모빌리언스 (046440)...
# Fetching 티이엠씨 (425040)...
# Fetching 이크레더블 (092130)...
# Fetching KEC (092220)...
# Fetching 사피엔반도체 (452430)...
# Fetching SK디앤디 (210980)...
# Fetching 우진 (105840)...
# Fetching 나이벡 (138610)...
# Fetching 일신석재 (007110)...
# Fetching 디케이티 (290550)...
# Fetching 아티스트유나이티드 (321820)...
# Fetching 대동전자 (008110)...
# Fetching 디와이피엔에프 (104460)...
# Fetching 보광산업 (225530)...
# Fetching 알에스오토메이션 (140670)...
# Fetching 한독 (002390)...
# Fetching 금호석유우 (011785)...
# Fetching 방림 (003610)...
# Fetching 퓨런티어 (370090)...
# Fetching 강남제비스코 (000860)...
# Fetching DMS (068790)...
# Fetching 컴투스홀딩스 (063080)...
# Fetching 한라IMS (092460)...
# Fetching 잉글우드랩 (950140)...
# Fetching 그린케미칼 (083420)...
# Fetching 네오위즈홀딩스 (042420)...
# Fetching 에이프로젠바이오로직스 (003060)...
# Fetching 대신증권2우B (003547)...
# Fetching NH올원리츠 (400760)...
# Fetching 녹십자웰빙 (234690)...
# Fetching 삼지전자 (037460)...
# Fetching 노루페인트 (090350)...
# Fetching 제일약품 (271980)...
# Fetching 이노와이어리스 (073490)...
# Fetching 대영포장 (014160)...
# Fetching S-Oil우 (010955)...
# Fetching 알서포트 (131370)...
# Fetching DSC인베스트먼트 (241520)...
# Fetching 대창단조 (015230)...
# Fetching 슈피겐코리아 (192440)...
# Fetching 딥노이드 (315640)...
# Fetching 금화피에스시 (036190)...
# Fetching 이지스레지던스리츠 (350520)...
# Fetching 한국제지 (027970)...
# Fetching 서울바이오시스 (092190)...
# Fetching 대한약품 (023910)...
# Fetching 온코닉테라퓨틱스 (476060)...
# Fetching 삼성출판사 (068290)...
# Fetching 비나텍 (126340)...
# Fetching 에이치이엠파마 (376270)...
# Fetching 일승 (333430)...
# Fetching 이랜시스 (264850)...
# Fetching 휴센텍 (215090)...
# Fetching 오스테오닉 (226400)...
# Fetching 케이씨에스 (115500)...
# Fetching 태림포장 (011280)...
# Fetching 레뷰코퍼레이션 (443250)...
# Fetching 한일사료 (005860)...
# Fetching CJ 바이오사이언스 (311690)...
# Fetching 에스비비테크 (389500)...
# Fetching 넥스트칩 (396270)...
# Fetching 유니퀘스트 (077500)...
# Fetching 대한화섬 (003830)...
# Fetching CJ우 (001045)...
# Fetching 와이즈넛 (096250)...
# Fetching 현대리바트 (079430)...
# Fetching 인텍플러스 (064290)...
# Fetching 삼성제약 (001360)...
# Fetching 벽산 (007210)...
# Fetching 코텍 (052330)...
# Fetching 네패스아크 (330860)...
# Fetching 경보제약 (214390)...
# Fetching 효성화학 (298000)...
# Fetching 이엠코리아 (095190)...
# Fetching 대원산업 (005710)...
# Fetching NPC (004250)...
# Fetching 디알텍 (214680)...
# Fetching 동양 (001520)...
# Fetching 아이티센 (124500)...
# Fetching 한양증권 (001750)...
# Fetching 엔바이오니아 (317870)...
# Fetching 경동인베스트 (012320)...
# Fetching 코다코 (046070)...
# Fetching 사조동아원 (008040)...
# Fetching 삼성공조 (006660)...
# Fetching 삼영 (003720)...
# Fetching 엑셈 (205100)...
# Fetching 제일엠앤에스 (412540)...
# Fetching 아톤 (158430)...
# Fetching 워트 (396470)...
# Fetching 이수화학 (005950)...
# Fetching 라파스 (214260)...
# Fetching 제노코 (361390)...
# Fetching AK홀딩스 (006840)...
# Fetching 유수홀딩스 (000700)...
# Fetching 포니링크 (064800)...
# Fetching 한국무브넥스 (010100)...
# Fetching 아이엠비디엑스 (461030)...
# Fetching 한국주철관 (000970)...
# Fetching 인벤티지랩 (389470)...
# Fetching 삼양통상 (002170)...
# Fetching 씨에스베어링 (297090)...
# Fetching 그린리소스 (402490)...
# Fetching 신라교역 (004970)...
# Fetching 디엔에이링크 (127120)...
# Fetching 씨앤지하이테크 (264660)...
# Fetching 아바텍 (149950)...
# Fetching 인트론바이오 (048530)...
# Fetching 동구바이오제약 (006620)...
# Fetching 팜스토리 (027710)...
# Fetching 태경산업 (015890)...
# Fetching 지투파워 (388050)...
# Fetching 대성산업 (128820)...
# Fetching 신흥 (004080)...
# Fetching 모티브링크 (463480)...
# Fetching 신원 (009270)...
# Fetching 보성파워텍 (006910)...
# Fetching 동양철관 (008970)...
# Fetching 애니플러스 (310200)...
# Fetching 현대바이오랜드 (052260)...
# Fetching 일진파워 (094820)...
# Fetching 나인테크 (267320)...
# Fetching 나노팀 (417010)...
# Fetching 다산네트웍스 (039560)...
# Fetching 한국경제TV (039340)...
# Fetching SM C&C (048550)...
# Fetching 고려신용정보 (049720)...
# Fetching 코리아에프티 (123410)...
# Fetching 아티스트스튜디오 (200350)...
# Fetching 한선엔지니어링 (452280)...
# Fetching 디와이파워 (210540)...
# Fetching 효성ITX (094280)...
# Fetching 선진 (136490)...
# Fetching 태경케미컬 (006890)...
# Fetching 테고사이언스 (191420)...
# Fetching YTN (040300)...
# Fetching 웹케시 (053580)...
# Fetching 피노 (033790)...
# Fetching 에이스테크 (088800)...
# Fetching 드림어스컴퍼니 (060570)...
# Fetching 윈스 (136540)...
# Fetching M83 (476080)...
# Fetching SG글로벌 (001380)...
# Fetching 비씨엔씨 (146320)...
# Fetching 더네이쳐홀딩스 (298540)...
# Fetching 선진뷰티사이언스 (086710)...
# Fetching 제닉스 (381620)...
# Fetching 자이언트스텝 (289220)...
# Fetching 위너스 (479960)...
# Fetching 헥토파이낸셜 (234340)...
# Fetching 한솔테크닉스 (004710)...
# Fetching 엘앤케이바이오 (156100)...
# Fetching 인크레더블버즈 (064090)...
# Fetching 유니슨 (018000)...
# Fetching 에스엠벡셀 (010580)...
# Fetching 아이텍 (119830)...
# Fetching 유화증권 (003460)...
# Fetching 시스웍 (269620)...
# Fetching 초록뱀미디어 (047820)...
# Fetching 디이엔티 (079810)...
# Fetching 코세스 (089890)...
# Fetching 스맥 (099440)...
# Fetching 율호 (072770)...
# Fetching 삼보판지 (023600)...
# Fetching 키다리스튜디오 (020120)...
# Fetching 케이알엠 (093640)...
# Fetching 에이치엔에스하이텍 (044990)...
# Fetching 이랜텍 (054210)...
# Fetching 삼성물산우B (02826K)...
# Fetching 범한퓨얼셀 (382900)...
# Fetching 케이엔제이 (272110)...
# Fetching 디씨엠 (024090)...
# Fetching 유한양행우 (000105)...
# Fetching 인피니트헬스케어 (071200)...
# Fetching 샌즈랩 (411080)...
# Fetching 금호에이치티 (214330)...
# Fetching 매일홀딩스 (005990)...
# Fetching 경남스틸 (039240)...
# Fetching KH 필룩스 (033180)...
# Fetching 대창 (012800)...
# Fetching 티케이케미칼 (104480)...
# Fetching 제이스코홀딩스 (023440)...
# Fetching 티에스아이 (277880)...
# Fetching 엠디바이스 (226590)...
# Fetching 국보디자인 (066620)...
# Fetching 아모레G3우(전환) (00279K)...
# Fetching 도이치모터스 (067990)...
# Fetching 티라유텍 (322180)...
# Fetching 지슨 (289860)...
# Fetching 대원미디어 (048910)...
# Fetching APS (054620)...
# Fetching 오성첨단소재 (052420)...
# Fetching 엠오티 (413390)...
# Fetching 강스템바이오텍 (217730)...
# Fetching 파마리서치바이오 (217950)...
# Fetching 유니켐 (011330)...
# Fetching 아시아나IDT (267850)...
# Fetching 메드팩토 (235980)...
# Fetching 메가스터디 (072870)...
# Fetching 광무 (029480)...
# Fetching 와이제이링크 (209640)...
# Fetching 자이에스앤디 (317400)...
# Fetching 온코크로스 (382150)...
# Fetching STX (011810)...
# Fetching 이니텍 (053350)...
# Fetching 지어소프트 (051160)...
# Fetching 태경비케이 (014580)...
# Fetching 두산2우B (000157)...
# Fetching 마음AI (377480)...
# Fetching 켐트로스 (220260)...
# Fetching 에스텍 (069510)...
# Fetching 쎌바이오텍 (049960)...
# Fetching 지니뮤직 (043610)...
# Fetching 한국첨단소재 (062970)...
# Fetching 그리드위즈 (453450)...
# Fetching 페이퍼코리아 (001020)...
# Fetching 조선선재 (120030)...
# Fetching 이지케어텍 (099750)...
# Fetching 푸른저축은행 (007330)...
# Fetching 에어레인 (163280)...
# Fetching 레이 (228670)...
# Fetching 현대이지웰 (090850)...
# Fetching 수산중공업 (017550)...
# Fetching 에이에스텍 (453860)...
# Fetching KIB플러그에너지 (015590)...
# Fetching 신세계푸드 (031440)...
# Fetching 아남전자 (008700)...
# Fetching 퓨처코어 (151910)...
# Fetching 바이오에프디엔씨 (251120)...
# Fetching 샘표 (007540)...
# Fetching 휴니드 (005870)...
# Fetching 블루엠텍 (439580)...
# Fetching HS애드 (035000)...
# Fetching 우리바이오 (082850)...
# Fetching 경인양행 (012610)...
# Fetching 동남합성 (023450)...
# Fetching 레이저옵텍 (199550)...
# Fetching 샘표식품 (248170)...
# Fetching 코웰패션 (033290)...
# Fetching 코어라인소프트 (384470)...
# Fetching 서울옥션 (063170)...
# Fetching 계룡건설 (013580)...
# Fetching SJG세종 (033530)...
# Fetching 농우바이오 (054050)...
# Fetching 스튜디오미르 (408900)...
# Fetching 코아스템켐온 (166480)...
# Fetching 제룡산업 (147830)...
# Fetching 서호전기 (065710)...
# Fetching HLB제넥스 (187420)...
# Fetching 동국S&C (100130)...
# Fetching 와이엠텍 (273640)...
# Fetching 디엔에프 (092070)...
# Fetching 크리스탈신소재 (900250)...
# Fetching 금강공업 (014280)...
# Fetching 라온테크 (232680)...
# Fetching 제일파마홀딩스 (002620)...
# Fetching 휴먼테크놀로지 (175140)...
# Fetching SBI핀테크솔루션즈 (950110)...
# Fetching 지앤비에스 에코 (382800)...
# Fetching 우수AMS (066590)...
# Fetching 싸이맥스 (160980)...
# Fetching 플리토 (300080)...
# Fetching 뉴프렉스 (085670)...
# Fetching 빅텍 (065450)...
# Fetching 태웅로직스 (124560)...
# Fetching 극동유화 (014530)...
# Fetching 청호ICT (012600)...
# Fetching 플래스크 (041590)...
# Fetching 팅크웨어 (084730)...
# Fetching 덕성 (004830)...
# Fetching KTcs (058850)...
# Fetching 셀바스헬스케어 (208370)...
# Fetching HDC현대EP (089470)...
# Fetching 화성밸브 (039610)...
# Fetching 수산아이앤티 (050960)...
# Fetching 티쓰리 (204610)...
# Fetching 풍국주정 (023900)...
# Fetching 와이엔텍 (067900)...
# Fetching 진흥기업 (002780)...
# Fetching HS효성 (487570)...
# Fetching 세아특수강 (019440)...
# Fetching 인포바인 (115310)...
# Fetching 진로발효 (018120)...
# Fetching 제로투세븐 (159580)...
# Fetching 청담글로벌 (362320)...
# Fetching 진양산업 (003780)...
# Fetching 하이로닉 (149980)...
# Fetching 제이아이테크 (417500)...
# Fetching 새로닉스 (042600)...
# Fetching KCTC (009070)...
# Fetching 부방 (014470)...
# Fetching SK시그넷 (260870)...
# Fetching 특수건설 (026150)...
# Fetching HLB파나진 (046210)...
# Fetching SBI인베스트먼트 (019550)...
# Fetching 케이엔에스 (432470)...
# Fetching 원익피앤이 (217820)...
# Fetching 우신시스템 (017370)...
# Fetching 대성홀딩스 (016710)...
# Fetching 조이시티 (067000)...
# Fetching 밀리의서재 (418470)...
# Fetching 라온시큐어 (042510)...
# Fetching CJ씨푸드 (011150)...
# Fetching 티와이홀딩스 (363280)...
# Fetching 아이에스티이 (212710)...
# Fetching 웨이비스 (289930)...
# Fetching 한울소재과학 (091440)...
# Fetching 파세코 (037070)...
# Fetching 크리스에프앤씨 (110790)...
# Fetching MDS테크 (086960)...
# Fetching 동방 (004140)...
# Fetching 나노엔텍 (039860)...
# Fetching LK삼양 (225190)...
# Fetching 노브랜드 (145170)...
# Fetching 트루엔 (417790)...
# Fetching 이브이첨단소재 (131400)...
# Fetching 한국수출포장 (002200)...
# Fetching 종근당바이오 (063160)...
# Fetching 아이씨디 (040910)...
# Fetching 유니트론텍 (142210)...
# Fetching 엠에스씨 (009780)...
# Fetching 미래에셋글로벌리츠 (396690)...
# Fetching 모베이스전자 (012860)...
# Fetching 한국화장품 (123690)...
# Fetching 팬엔터테인먼트 (068050)...
# Fetching 에이팩트 (200470)...
# Fetching 에이치피오 (357230)...
# Fetching 유라테크 (048430)...
# Fetching 오이솔루션 (138080)...
# Fetching 인천도시가스 (034590)...
# Fetching 오파스넷 (173130)...
# Fetching 솔본 (035610)...
# Fetching 옵투스제약 (131030)...
# Fetching 신테카바이오 (226330)...
# Fetching 신스틸 (162300)...
# Fetching 에이텍모빌리티 (224110)...
# Fetching 유비쿼스 (264450)...
# Fetching 한국특강 (007280)...
# Fetching 나우IB (293580)...
# Fetching 네오이뮨텍 (950220)...
# Fetching 디에스케이 (109740)...
# Fetching 엔지켐생명과학 (183490)...
# Fetching 샤페론 (378800)...
# Fetching 네온테크 (306620)...
# Fetching 퓨릿 (445180)...
# Fetching 세운메디칼 (100700)...
# Fetching 상신이디피 (091580)...
# Fetching 세보엠이씨 (011560)...
# Fetching 레이언스 (228850)...
# Fetching 아모텍 (052710)...
# Fetching 예스24 (053280)...
# Fetching 위닉스 (044340)...
# Fetching 덴티스 (261200)...
# Fetching 리드코프 (012700)...
# Fetching 금양그린파워 (282720)...
# Fetching 삼익악기 (002450)...
# Fetching 고스트스튜디오 (950190)...
# Fetching 만호제강 (001080)...
# Fetching 현대약품 (004310)...
# Fetching 헬릭스미스 (084990)...
# Fetching 엠벤처투자 (019590)...
# Fetching 알에프텍 (061040)...
# Fetching 코칩 (126730)...
# Fetching 선광 (003100)...
# Fetching 메타바이오메드 (059210)...
# Fetching 꿈비 (407400)...
# Fetching 오킨스전자 (080580)...
# Fetching 한진중공업홀딩스 (003480)...
# Fetching 모나리자 (012690)...
# Fetching 에스트래픽 (234300)...
# Fetching 와이바이오로직스 (338840)...
# Fetching 광전자 (017900)...
# Fetching 신일전자 (002700)...
# Fetching 아진산업 (013310)...
# Fetching 삼부토건 (001470)...
# Fetching 동일고무벨트 (163560)...
# Fetching 에코플라스틱 (038110)...
# Fetching 홈센타홀딩스 (060560)...
# Fetching 경동도시가스 (267290)...
# Fetching 남화산업 (111710)...
# Fetching 평화홀딩스 (010770)...
# Fetching 디와이 (013570)...
# Fetching KNN (058400)...
# Fetching 이엠티 (232530)...
# Fetching 삼아제약 (009300)...
# Fetching 동성제약 (002210)...
# Fetching 에이엘티 (172670)...
# Fetching iMBC (052220)...
# Fetching 대한뉴팜 (054670)...
# Fetching 공구우먼 (366030)...
# Fetching 테라젠이텍스 (066700)...
# Fetching 엘티씨 (170920)...
# Fetching 한솔홀딩스 (004150)...
# Fetching 메카로 (241770)...
# Fetching 케이엔알시스템 (199430)...
# Fetching 국제약품 (002720)...
# Fetching 베뉴지 (019010)...
# Fetching 야스 (255440)...
# Fetching 삐아 (451250)...
# Fetching 엠플러스 (259630)...
# Fetching 엑스페릭스 (317770)...
# Fetching 제이씨현시스템 (033320)...
# Fetching 한송네오텍 (226440)...
# Fetching 에이티넘인베스트 (021080)...
# Fetching 휴비츠 (065510)...
# Fetching 토마토시스템 (393210)...
# Fetching 유아이엘 (049520)...
# Fetching 한신기계 (011700)...
# Fetching SK이노베이션우 (096775)...
# Fetching 태양금속 (004100)...
# Fetching 한스바이오메드 (042520)...
# Fetching NI스틸 (008260)...
# Fetching 버킷스튜디오 (066410)...
# Fetching 빅솔론 (093190)...
# Fetching 크라운제과 (264900)...
# Fetching 지니언스 (263860)...
# Fetching 조흥 (002600)...
# Fetching 코츠테크놀로지 (448710)...
# Fetching 싸이토젠 (217330)...
# Fetching 대성창투 (027830)...
# Fetching HS화성 (002460)...
# Fetching 코메론 (049430)...
# Fetching 서원인텍 (093920)...
# Fetching 위츠 (459100)...
# Fetching 코리아나 (027050)...
# Fetching 차이커뮤니케이션 (351870)...
# Fetching 와이랩 (432430)...
# Fetching 3S (060310)...
# Fetching 중앙백신 (072020)...
# Fetching 수성웹툰 (084180)...
# Fetching 엔젯 (419080)...
# Fetching 동일산업 (004890)...
# Fetching 아모그린텍 (125210)...
# Fetching 두올 (016740)...
# Fetching 한국피아이엠 (448900)...
# Fetching 이노메트리 (302430)...
# Fetching 서플러스글로벌 (140070)...
# Fetching 대보마그네틱 (290670)...
# Fetching 대현 (016090)...
# Fetching AP헬스케어 (109960)...
# Fetching 지오엘리먼트 (311320)...
# Fetching 아이에이 (038880)...
# Fetching 세코닉스 (053450)...
# Fetching 에스피시스템스 (317830)...
# Fetching 민테크 (452200)...
# Fetching 블랙야크아이앤씨 (478560)...
# Fetching 엠게임 (058630)...
# Fetching 큐라클 (365270)...
# Fetching 동인기연 (111380)...
# Fetching 제이엔케이글로벌 (126880)...
# Fetching 리메드 (302550)...
# Fetching 현대코퍼레이션홀딩스 (227840)...
# Fetching 한컴라이프케어 (372910)...
# Fetching 노을 (376930)...
# Fetching 삼보모터스 (053700)...
# Fetching 메디아나 (041920)...
# Fetching 금호건설 (002990)...
# Fetching 인크로스 (216050)...
# Fetching 수젠텍 (253840)...
# Fetching 유비벨록스 (089850)...
# Fetching 삼원강재 (023000)...
# Fetching 엠투아이 (347890)...
# Fetching 크레오에스지 (040350)...
# Fetching 인지컨트롤스 (023800)...
# Fetching 대정화금 (120240)...
# Fetching 신영와코루 (005800)...
# Fetching 아이디스홀딩스 (054800)...
# Fetching 제이씨케미칼 (137950)...
# Fetching 피앤에스미캐닉스 (460940)...
# Fetching 시지메드텍 (056090)...
# Fetching 파로스아이바이오 (388870)...
# Fetching 메쎄이상 (408920)...
# Fetching 영보화학 (014440)...
# Fetching 덕양산업 (024900)...
# Fetching 코스맥스비티아이 (044820)...
# Fetching 하이드로리튬 (101670)...
# Fetching 에스엠코어 (007820)...
# Fetching 화일약품 (061250)...
# Fetching 케이옥션 (102370)...
# Fetching 우리손에프앤지 (073560)...
# Fetching 삼기이브이 (419050)...
# Fetching 고바이오랩 (348150)...
# Fetching 광림 (014200)...
# Fetching 데이원컴퍼니 (373160)...
# Fetching 대명소노시즌 (007720)...
# Fetching 엔에스이엔엠 (078860)...
# Fetching 네오크레마 (311390)...
# Fetching 삼미금속 (012210)...
# Fetching 세이브존I&C (067830)...
# Fetching 성창기업지주 (000180)...
# Fetching 아이비김영 (339950)...
# Fetching 한국선재 (025550)...
# Fetching KTis (058860)...
# Fetching 엔브이에이치코리아 (067570)...
# Fetching 에이플러스에셋 (244920)...
# Fetching 하이딥 (365590)...
# Fetching DXVX (180400)...
# Fetching 휴비스 (079980)...
# Fetching 피제이전자 (006140)...
# Fetching 세명전기 (017510)...
# Fetching 지아이텍 (382480)...
# Fetching 대호에이엘 (069460)...
# Fetching 스톰테크 (352090)...
# Fetching 우리산업 (215360)...
# Fetching 에프엔에스테크 (083500)...
# Fetching 제일연마 (001560)...
# Fetching 티움바이오 (321550)...
# Fetching 한국내화 (010040)...
# Fetching 아셈스 (136410)...
# Fetching 형지엘리트 (093240)...
# Fetching 하이스틸 (071090)...
# Fetching 현대공업 (170030)...
# Fetching 유니온머티리얼 (047400)...
# Fetching 황금에스티 (032560)...
# Fetching 정상제이엘에스 (040420)...
# Fetching 진양화학 (051630)...
# Fetching 사조씨푸드 (014710)...
# Fetching 코아시아 (045970)...
# Fetching 라온피플 (300120)...
# Fetching 동원금속 (018500)...
# Fetching 비아트론 (141000)...
# Fetching 케이피에프 (024880)...
# Fetching 지에스이 (053050)...
# Fetching 메가터치 (446540)...
# Fetching 엔시스 (333620)...
# Fetching 큐에스아이 (066310)...
# Fetching 중앙에너비스 (000440)...
# Fetching 쓰리에이로직스 (177900)...
# Fetching 셀리드 (299660)...
# Fetching 상상인 (038540)...
# Fetching KCC건설 (021320)...
# Fetching 엘컴텍 (037950)...
# Fetching 녹십자엠에스 (142280)...
# Fetching 오리콤 (010470)...
# Fetching 이닉스 (452400)...
# Fetching 폴라리스AI파마 (041910)...
# Fetching 위지트 (036090)...
# Fetching 새빗켐 (107600)...
# Fetching 무림페이퍼 (009200)...
# Fetching 인성정보 (033230)...
# Fetching 씨티케이 (260930)...
# Fetching 안국약품 (001540)...
# Fetching 깨끗한나라 (004540)...
# Fetching HL D&I (014790)...
# Fetching LB인베스트먼트 (309960)...
# Fetching 신송홀딩스 (006880)...
# Fetching 비엠티 (086670)...
# Fetching 세종텔레콤 (036630)...
# Fetching 대구백화점 (006370)...
# Fetching 동아화성 (041930)...
# Fetching DRB동일 (004840)...
# Fetching 제이스텍 (090470)...
# Fetching 미스터블루 (207760)...
# Fetching 에이비프로바이오 (195990)...
# Fetching 핑거 (163730)...
# Fetching 디케이락 (105740)...
# Fetching 링네트 (042500)...
# Fetching NH프라임리츠 (338100)...
# Fetching 윙입푸드 (900340)...
# Fetching 유니온 (000910)...
# Fetching 제노레이 (122310)...
# Fetching 화승코퍼레이션 (013520)...
# Fetching 텔코웨어 (078000)...
# Fetching 미래생명자원 (218150)...
# Fetching 마이크로컨텍솔 (098120)...
# Fetching 라이온켐텍 (171120)...
# Fetching CS홀딩스 (000590)...
# Fetching 키이스트 (054780)...
# Fetching 라온텍 (418420)...
# Fetching 위더스제약 (330350)...
# Fetching 와이투솔루션 (011690)...
# Fetching 정다운 (208140)...
# Fetching 아미노로직스 (074430)...
# Fetching 동부건설 (005960)...
# Fetching 로보로보 (215100)...
# Fetching 동방아그로 (007590)...
# Fetching 디티앤씨알오 (383930)...
# Fetching 모비스 (250060)...
# Fetching 세토피아 (222810)...
# Fetching 창해에탄올 (004650)...
# Fetching 타이거일렉 (219130)...
# Fetching 컴퍼니케이 (307930)...
# Fetching 에스넷 (038680)...
# Fetching NE능률 (053290)...
# Fetching 티웨이홀딩스 (004870)...
# Fetching HRS (036640)...
# Fetching 비트컴퓨터 (032850)...
# Fetching 남광토건 (001260)...
# Fetching 국순당 (043650)...
# Fetching 디와이디 (219550)...
# Fetching 퀀타매트릭스 (317690)...
# Fetching 그린플러스 (186230)...
# Fetching 바이오스마트 (038460)...
# Fetching 영화테크 (265560)...
# Fetching 옵티팜 (153710)...
# Fetching 아이엠티 (451220)...
# Fetching 비아이매트릭스 (413640)...
# Fetching 인스피언 (465480)...
# Fetching 포바이포 (389140)...
# Fetching 오픈놀 (440320)...
# Fetching 사조오양 (006090)...
# Fetching 크라운해태홀딩스 (005740)...
# Fetching 씨씨에스 (066790)...
# Fetching 써니전자 (004770)...
# Fetching 한컴위드 (054920)...
# Fetching 프로젠 (296160)...
# Fetching 진양제약 (007370)...
# Fetching NPX (222160)...
# Fetching 코렌텍 (104540)...
# Fetching 에프앤가이드 (064850)...
# Fetching 유니테크노 (241690)...
# Fetching 이건홀딩스 (039020)...
# Fetching 아이엘사이언스 (307180)...
# Fetching 신신제약 (002800)...
# Fetching 서한 (011370)...
# Fetching 차백신연구소 (261780)...
# Fetching 블리츠웨이스튜디오 (369370)...
# Fetching 티비씨 (033830)...
# Fetching 피제이메탈 (128660)...
# Fetching 위메이드플레이 (123420)...
# Fetching 시공테크 (020710)...
# Fetching 부산산업 (011390)...
# Fetching 덕우전자 (263600)...
# Fetching 미래에셋드림스팩1호 (442900)...
# Fetching 세원정공 (021820)...
# Fetching 이스타코 (015020)...
# Fetching 윈팩 (097800)...
# Fetching 에이스토리 (241840)...
# Fetching 엔피 (291230)...
# Fetching 참좋은여행 (094850)...
# Fetching 팜스코 (036580)...
# Fetching 남양유업우 (003925)...
# Fetching 신일제약 (012790)...
# Fetching 디바이스이엔지 (187870)...
# Fetching 티디에스팜 (464280)...
# Fetching 액토즈소프트 (052790)...
# Fetching 금강철강 (053260)...
# Fetching 현대ADM (187660)...
# Fetching SCI평가정보 (036120)...
# Fetching 호전실업 (111110)...
# Fetching 티플랙스 (081150)...
# Fetching 우리넷 (115440)...
# Fetching 아비코전자 (036010)...
# Fetching 우림피티에스 (101170)...
# Fetching 한일단조 (024740)...
# Fetching 삼호개발 (010960)...
# Fetching 강동씨앤엘 (198440)...
# Fetching 노랑풍선 (104620)...
# Fetching 아이빔테크놀로지 (460470)...
# Fetching 모델솔루션 (417970)...
# Fetching 팜젠사이언스 (004720)...
# Fetching 라이콤 (388790)...
# Fetching JW신약 (067290)...
# Fetching 아진엑스텍 (059120)...
# Fetching 탑엔지니어링 (065130)...
# Fetching 대모 (317850)...
# Fetching 이녹스 (088390)...
# Fetching 한켐 (457370)...
# Fetching 알비더블유 (361570)...
# Fetching 인터지스 (129260)...
# Fetching 선바이오 (067370)...
# Fetching 유유제약 (000220)...
# Fetching 지놈앤컴퍼니 (314130)...
# Fetching 이엘씨 (041520)...
# Fetching 유일에너테크 (340930)...
# Fetching 피에스텍 (002230)...
# Fetching 에이프로 (262260)...
# Fetching 조광페인트 (004910)...
# Fetching 플레이디 (237820)...
# Fetching 까뮤이앤씨 (013700)...
# Fetching 한국컴퓨터 (054040)...
# Fetching 오픈베이스 (049480)...
# Fetching 심텍홀딩스 (036710)...
# Fetching 해성에어로보틱스 (059270)...
# Fetching 동일금속 (109860)...
# Fetching 센코 (347000)...
# Fetching 위드텍 (348350)...
# Fetching 셀루메드 (049180)...
# Fetching 희림 (037440)...
# Fetching KBI메탈 (024840)...
# Fetching 서남 (294630)...
# Fetching 오로라 (039830)...
# Fetching 모베이스 (101330)...
# Fetching 제너셈 (217190)...
# Fetching 잉크테크 (049550)...
# Fetching 데이타솔루션 (263800)...
# Fetching 토탈소프트 (045340)...
# Fetching 콤텍시스템 (031820)...
# Fetching 나이스디앤비 (130580)...
# Fetching 소마젠 (950200)...
# Fetching SV인베스트먼트 (289080)...
# Fetching 한신공영 (004960)...
# Fetching RF시스템즈 (474610)...
# Fetching 제이투케이바이오 (420570)...
# Fetching 유엔젤 (072130)...
# Fetching 스톤브릿지벤처스 (330730)...
# Fetching 엠투엔 (033310)...
# Fetching 코스맥스엔비티 (222040)...
# Fetching 브이원텍 (251630)...
# Fetching 지엠비코리아 (013870)...
# Fetching 레몬 (294140)...
# Fetching 알리코제약 (260660)...
# Fetching 에스엠씨지 (460870)...
# Fetching 엔케이 (085310)...
# Fetching 아모센스 (357580)...
# Fetching KCI (036670)...
# Fetching 진시스템 (363250)...
# Fetching 화인써키트 (127980)...
# Fetching 캔버스엔 (210120)...
# Fetching 아스타 (246720)...
# Fetching 원익 (032940)...
# Fetching 코닉오토메이션 (391710)...
# Fetching 알파홀딩스 (117670)...
# Fetching 코콤 (015710)...
# Fetching 라메디텍 (462510)...
# Fetching 지엘팜텍 (204840)...
# Fetching 폴라리스세원 (234100)...
# Fetching 일동홀딩스 (000230)...
# Fetching 쌍방울 (102280)...
# Fetching 기신정기 (092440)...
# Fetching 티앤알바이오팹 (246710)...
# Fetching 프리엠스 (053160)...
# Fetching 에이치시티 (072990)...
# Fetching SKAI (357880)...
# Fetching 하츠 (066130)...
# Fetching 한솔홈데코 (025750)...
# Fetching 조광ILI (044060)...
# Fetching 흥국에프엔비 (189980)...
# Fetching 인바이오젠 (101140)...
# Fetching 시그네틱스 (033170)...
# Fetching 덕신이피씨 (090410)...
# Fetching 아크솔루션스 (203690)...
# Fetching 고려산업 (002140)...
# Fetching 테라사이언스 (073640)...
# Fetching 하스 (450330)...
# Fetching 씨앤투스 (352700)...
# Fetching 상보 (027580)...
# Fetching 드림씨아이에스 (223250)...
# Fetching 와이어블 (065530)...
# Fetching 에스씨디 (042110)...
# Fetching SK우 (03473K)...
# Fetching 삼현철강 (017480)...
# Fetching 포인트엔지니어링 (256630)...
# Fetching PN풍년 (024940)...
# Fetching 유성티엔에스 (024800)...
# Fetching 아이진 (185490)...
# Fetching 성안머티리얼스 (011300)...
# Fetching 이렘 (009730)...
# Fetching TP (007980)...
# Fetching 도부 (227420)...
# Fetching 웅진 (016880)...
# Fetching 사이냅소프트 (466410)...
# Fetching 성호전자 (043260)...
# Fetching 화천기계 (010660)...
# Fetching 홈캐스트 (064240)...
# Fetching 오르비텍 (046120)...
# Fetching 대한광통신 (010170)...
# Fetching 신한글로벌액티브리츠 (481850)...
# Fetching 슈프리마에이치큐 (094840)...
# Fetching KS인더스트리 (101000)...
# Fetching 유니크 (011320)...
# Fetching 알티캐스트 (085810)...
# Fetching 한울반도체 (320000)...
# Fetching 아스플로 (159010)...
# Fetching 엔지스테크널러지 (208860)...
# Fetching 피엔케이피부임상연구센타 (347740)...
# Fetching 와이엠씨 (155650)...
# Fetching 캐리소프트 (317530)...
# ...
# Fetching 키네마스터 (139670)...
# Fetching 캐스텍코리아 (071850)...
# Fetching 네오펙트 (290660)...
# Fetching 디에이테크놀로지 (196490)...
# Fetching DH오토리드 (290120)...
# Fetching KB오토시스 (024120)...
# Fetching 엠에프씨 (432980)...
# Fetching 이에이트 (418620)...
# Fetching 팬스타엔터프라이즈 (054300)...
# Fetching 오디텍 (080520)...
# Fetching 이씨에스 (067010)...
# Fetching 한창산업 (079170)...
# Fetching 케일럼 (258610)...
# Fetching 아이컴포넌트 (059100)...
# Fetching 빛샘전자 (072950)...
# Fetching 마이크로투나노 (424980)...
# Fetching 성우전자 (081580)...
# Fetching 유진테크놀로지 (240600)...
# Fetching HLB사이언스 (343090)...
# Fetching 씨유메디칼 (115480)...
# Fetching 티에스넥스젠 (043220)...
# Fetching 신원종합개발 (017000)...
# Fetching 세화피앤씨 (252500)...
# Fetching 세우글로벌 (013000)...
# Fetching SUN&L (002820)...
# Fetching 휴림에이텍 (078590)...
# Fetching 디티앤씨 (187220)...
# Fetching 동양파일 (228340)...
# Fetching 나라셀라 (405920)...
# Fetching 아이비젼웍스 (469750)...
# Fetching 대성미생물 (036480)...
# Fetching 카이노스메드 (284620)...
# Fetching 삼보산업 (009620)...
# Fetching 핌스 (347770)...
# Fetching 나우코스 (257990)...
# Fetching 메타랩스 (090370)...
# Fetching 화인베스틸 (133820)...
# Fetching 조아제약 (034940)...
# Fetching 한빛소프트 (047080)...
# Fetching 에스지헬스케어 (398120)...
# Fetching 한세엠케이 (069640)...
# Fetching 제주맥주 (276730)...
# Fetching CBI (013720)...
# Fetching 나래나노텍 (137080)...
# Fetching 신도기연 (290520)...
# Fetching 엔젠바이오 (354200)...
# Fetching 플래티어 (367000)...
# Fetching 플레이위드 (023770)...
# Fetching 하이퍼코퍼레이션 (065650)...
# Fetching 시큐브 (131090)...
# Fetching 스킨앤스킨 (159910)...
# Fetching DH오토웨어 (025440)...
# Fetching S&K폴리텍 (091340)...
# Fetching 스튜디오삼익 (415380)...
# Fetching 모헨즈 (006920)...
# Fetching 아이윈 (090150)...
# Fetching 지니틱스 (303030)...
# Fetching 누보 (332290)...
# Fetching 케이쓰리아이 (431190)...
# Fetching 그린생명과학 (114450)...
# Fetching 코스텍시스템 (169670)...
# Fetching 소프트센 (032680)...
# Fetching 국보 (001140)...
# Fetching 아이크래프트 (052460)...
# Fetching 솔루스첨단소재1우 (33637K)...
# Fetching 휴네시온 (290270)...
# Fetching 씨유박스 (340810)...
# Fetching TPC (048770)...
# Fetching 넥스트아이 (137940)...
# Fetching 한국전자홀딩스 (006200)...
# Fetching 코아스 (071950)...
# Fetching 아하 (102950)...
# Fetching 유비씨 (495810)...
# Fetching 전방 (000950)...
# Fetching 율촌 (146060)...
# Fetching 레이저쎌 (412350)...
# Fetching DL우 (000215)...
# Fetching 솔트웨어 (328380)...
# Fetching 삼일 (032280)...
# Fetching 파인디지털 (038950)...
# Fetching 아우딘퓨쳐스 (227610)...
# Fetching 원림 (005820)...
# Fetching 이노룰스 (296640)...
# Fetching 대한과학 (131220)...
# Fetching 비큐AI (148780)...
# Fetching 크린앤사이언스 (045520)...
# Fetching 듀오백 (073190)...
# Fetching 이미지스 (115610)...
# Fetching 나노 (187790)...
# Fetching 프리시젼바이오 (335810)...
# Fetching 무림SP (001810)...
# Fetching 원일특강 (012620)...
# Fetching 다이나믹디자인 (145210)...
# Fetching 누리플렉스 (040160)...
# Fetching 제이에스티나 (026040)...
# Fetching 디와이씨 (310870)...
# Fetching 모코엠시스 (333050)...
# Fetching 부스타 (008470)...
# Fetching 멕아이씨에스 (058110)...
# Fetching 디지캡 (197140)...
# Fetching 에넥스 (011090)...
# Fetching 신화콘텍 (187270)...
# Fetching 코퍼스코리아 (322780)...
# Fetching 바스칸바이오제약 (354390)...
# Fetching 넥스턴바이오 (089140)...
# Fetching 오스템 (031510)...
# Fetching 케이웨더 (068100)...
# Fetching ES큐브 (050120)...
# Fetching 에스티오 (098660)...
# Fetching 성우테크론 (045300)...
# Fetching TS트릴리온 (317240)...
# Fetching KC코트렐 (119650)...
# Fetching 리튬포어스 (073570)...
# Fetching 한성기업 (003680)...
# Fetching 아센디오 (012170)...
# Fetching 셀피글로벌 (068940)...
# Fetching 피엠티 (147760)...
# Fetching 큐라켐 (456190)...
# Fetching 바른손 (018700)...
# Fetching 바른손이앤에이 (035620)...
# Fetching 기산텔레콤 (035460)...
# Fetching 엔에이치스팩29호 (451700)...
# Fetching 이화산업 (000760)...
# Fetching 경인전자 (009140)...
# Fetching 볼빅 (206950)...
# Fetching 제넨바이오 (072520)...
# Fetching 링크드 (193250)...
# Fetching 우리엔터프라이즈 (037400)...
# Fetching 로지시스 (067730)...
# Fetching WISCOM (024070)...
# Fetching 라닉스 (317120)...
# Fetching 세기상사 (002420)...
# Fetching 한화투자증권우 (003535)...
# Fetching 브이씨 (365900)...
# Fetching 온타이드 (005320)...
# Fetching 틸론 (217880)...
# Fetching 웰크론한텍 (076080)...
# Fetching 아이티센코어 (243870)...
# Fetching 세방우 (004365)...
# Fetching 세중 (039310)...
# Fetching 팜스빌 (318010)...
# Fetching 메디앙스 (014100)...
# Fetching 메디쎄이 (200580)...
# Fetching 영우디에스피 (143540)...
# Fetching 참엔지니어링 (009310)...
# Fetching 휴맥스홀딩스 (028080)...
# Fetching SGA솔루션즈 (184230)...
# Fetching 젠큐릭스 (229000)...
# Fetching 대한방직 (001070)...
# Fetching 진바이오텍 (086060)...
# Fetching 아즈텍WB (032080)...
# Fetching 동양에스텍 (060380)...
# Fetching 라피치 (403360)...
# Fetching 에스에너지 (095910)...
# Fetching 압타머사이언스 (291650)...
# Fetching 머니무브 (179720)...
# Fetching 유디엠텍 (389680)...
# Fetching 협진 (138360)...
# Fetching 신풍제약우 (019175)...
# Fetching 판타지오 (032800)...
# Fetching 에피바이오텍 (446440)...
# Fetching 휴럼 (353190)...
# Fetching 아이스크림에듀 (289010)...
# Fetching 케이바이오 (038530)...
# Fetching 아이티아이즈 (372800)...
# Fetching 시큐센 (232830)...
# Fetching BYC우 (001465)...
# Fetching 하이즈항공 (221840)...
# Fetching 코아시아씨엠 (196450)...
# Fetching 선샤인푸드 (217620)...
# Fetching 엔시트론 (101400)...
# Fetching 태원물산 (001420)...
# Fetching 이엠앤아이 (083470)...
# Fetching 제이엠아이 (033050)...
# Fetching 지엔코 (065060)...
# Fetching 한주라이트메탈 (198940)...
# Fetching 이스트아시아홀딩스 (900110)...
# Fetching 위니아에이드 (377460)...
# Fetching 블루탑 (191600)...
# Fetching 우정바이오 (215380)...
# Fetching 삼영에스앤씨 (361670)...
# Fetching 한탑 (002680)...
# Fetching 딜리 (131180)...
# Fetching KB제27호스팩 (464680)...
# Fetching 엑스큐어 (070300)...
# Fetching 성창오토텍 (080470)...
# Fetching 우진비앤지 (018620)...
# Fetching 정원엔시스 (045510)...
# Fetching 관악산업 (076340)...
# Fetching 동일제강 (002690)...
# Fetching 나노씨엠에스 (247660)...
# Fetching 노드메이슨 (317860)...
# Fetching 뉴인텍 (012340)...
# Fetching 피앤씨테크 (237750)...
# Fetching 성문전자 (014910)...
# Fetching 대교우B (019685)...
# Fetching 풍강 (093380)...
# Fetching 에스엘에스바이오 (246250)...
# Fetching 클리노믹스 (352770)...
# Fetching 셀레믹스 (331920)...
# Fetching 핀텔 (291810)...
# Fetching 동일스틸럭스 (023790)...
# Fetching 엑사이엔씨 (054940)...
# Fetching 에이에프더블류 (312610)...
# Fetching 한국정밀기계 (101680)...
# Fetching 비피도 (238200)...
# Fetching 지란지교시큐리티 (208350)...
# Fetching 손오공 (066910)...
# Fetching 바이오인프라 (199730)...
# Fetching 에스폴리텍 (050760)...
# Fetching 에이펙스인텍 (207490)...
# Fetching 인바이오 (352940)...
# Fetching 서산 (079650)...
# Fetching 전진바이오팜 (110020)...
# Fetching 신시웨이 (290560)...
# Fetching 대한항공우 (003495)...
# Fetching BF랩스 (139050)...
# Fetching 와이오엠 (066430)...
# Fetching 에스씨엠생명과학 (298060)...
# Fetching 패션플랫폼 (225590)...
# Fetching 호텔신라우 (008775)...
# Fetching 대상우 (001685)...
# Fetching 한솔PNS (010420)...
# Fetching 씨엔플러스 (115530)...
# Fetching KR모터스 (000040)...
# Fetching TBH글로벌 (084870)...
# Fetching 신라에스지 (025870)...
# Fetching 스튜디오산타클로스 (204630)...
# Fetching 메디안디노스틱 (233250)...
# Fetching 비츠로시스 (054220)...
# Fetching 인터엠 (017250)...
# Fetching 한창 (005110)...
# Fetching 비비안 (002070)...
# Fetching 한주에이알티 (058450)...
# Fetching 삼성스팩9호 (468510)...
# Fetching 동원수산 (030720)...
# Fetching 오에스피 (368970)...
# Fetching 알로이스 (297570)...
# Fetching 무진메디 (322970)...
# Fetching 대산F&B (065150)...
# Fetching 안지오랩 (251280)...
# Fetching 엔지브이아이 (093510)...
# Fetching 세종메디칼 (258830)...
# Fetching EMB (278990)...
# Fetching 두산퓨얼셀2우B (33626L)...
# Fetching 플럼라인생명과학 (222670)...
# Fetching 소프트캠프 (258790)...
# Fetching 진코스텍 (250030)...
# Fetching 주연테크 (044380)...
# Fetching 진도 (088790)...
# Fetching 미래아이앤지 (007120)...
# Fetching 엘에이티 (311060)...
# Fetching 엑시온그룹 (069920)...
# Fetching 에이엔피 (015260)...
# Fetching 우진아이엔에스 (010400)...
# Fetching 신라섬유 (001000)...
# Fetching DGP (060900)...
# Fetching 위니아 (071460)...
# Fetching 대동금속 (020400)...
# Fetching 아이케이세미콘 (149010)...
# Fetching 토박스코리아 (215480)...
# Fetching 알파녹스 (043100)...
# Fetching 롯데지주우 (00499K)...
# Fetching 한국정보공학 (039740)...
# Fetching 이성씨엔아이 (379390)...
# Fetching 에스앤더블류 (103230)...
# Fetching 한국유니온제약 (080720)...
# Fetching 파인테크닉스 (106240)...
# Fetching 아시아종묘 (154030)...
# Fetching 비유테크놀러지 (230980)...
# Fetching 에스디시스템 (121890)...
# Fetching 해성옵틱스 (076610)...
# Fetching 파루 (043200)...
# Fetching 유비온 (084440)...
# Fetching 로스웰 (900260)...
# Fetching 더콘텐츠온 (302920)...
# Fetching 동양고속 (084670)...
# Fetching 대상홀딩스우 (084695)...
# Fetching 네오리진 (094860)...
# Fetching 메디콕스 (054180)...
# Fetching 인콘 (083640)...
# Fetching 알톤 (123750)...
# Fetching 글로벌에스엠 (900070)...
# Fetching 이노진 (344860)...
# Fetching 나노캠텍 (091970)...
# Fetching 한국ANKOR유전 (152550)...
# Fetching 유안타제13호스팩 (449020)...
# Fetching 에이치케이 (044780)...
# Fetching 티피씨글로벌 (130740)...
# Fetching 스타플렉스 (115570)...
# Fetching 한국주강 (025890)...
# Fetching 엔피케이 (048830)...
# Fetching 대호특수강 (021040)...
# Fetching 타스컴 (336040)...
# Fetching 케이피티유 (054410)...
# Fetching 시지트로닉스 (429270)...
# Fetching 오가닉티코스메틱 (900300)...
# Fetching 한국미라클피플사 (331660)...
# Fetching 웰킵스하이텍 (043590)...
# Fetching 디모아 (016670)...
# Fetching 대신밸런스제15호스팩 (457390)...
# Fetching 국일신동 (060480)...
# Fetching 세븐브로이맥주 (267080)...
# Fetching 피씨엘 (241820)...
# Fetching 이퓨쳐 (134060)...
# Fetching 빌리언스 (044480)...
# Fetching 에스에스알 (275630)...
# Fetching 엔에이치스팩26호 (439410)...
# Fetching 세니젠 (188260)...
# Fetching LX하우시스우 (108675)...
# Fetching 넥센타이어1우B (002355)...
# Fetching 유아이디 (069330)...
# Fetching 골드앤에스 (035290)...
# Fetching 이엘피 (063760)...
# Fetching 플라즈맵 (405000)...
# Fetching 원풍물산 (008290)...
# Fetching 로지스몬 (223220)...
# Fetching 드래곤플라이 (030350)...
# Fetching 녹십자홀딩스2우 (005257)...
# Fetching 케스피온 (079190)...
# Fetching 이노인스트루먼트 (215790)...
# Fetching 다산솔루에타 (154040)...
# Fetching 엔에이치스팩30호 (466910)...
# Fetching 타조엔터테인먼트 (476710)...
# Fetching 삼진엘앤디 (054090)...
# Fetching 삼양홀딩스우 (000075)...
# Fetching 세진티에스 (067770)...
# Fetching 앤씨앤 (092600)...
# Fetching 세동 (053060)...
# Fetching SHD (001770)...
# Fetching 베셀 (177350)...
# Fetching 까스텔바작 (308100)...
# Fetching 에스아이리소스 (065420)...
# Fetching 데이터스트림즈 (199150)...
# Fetching KC그린홀딩스 (009440)...
# Fetching 바이오텐 (289170)...
# Fetching 스타코링크 (060240)...
# Fetching 서울전자통신 (027040)...
# Fetching 누리플랜 (069140)...
# Fetching SGA (049470)...
# Fetching 엘디티 (096870)...
# Fetching 하이트진로2우B (000087)...
# Fetching 육일씨엔에쓰 (191410)...
# Fetching 코리아써우 (007815)...
# Fetching 애드바이오텍 (179530)...
# Fetching 미쥬 (351020)...
# Fetching THE E&M (089230)...
# Fetching 플루토스 (019570)...
# Fetching 대덕전자1우 (35320K)...
# Fetching 에프알텍 (073540)...
# Fetching KB제26호스팩 (458320)...
# Fetching 씨엑스아이 (900120)...
# Fetching 코오롱우 (002025)...
# Fetching 엔에이치스팩27호 (440820)...
# Fetching 대신밸런스제18호스팩 (478780)...
# Fetching 제이준코스메틱 (025620)...
# Fetching 웹스 (196700)...
# Fetching 애니메디솔루션 (390110)...
# Fetching 미래에셋비전스팩7호 (482680)...
# Fetching 벨로크 (424760)...
# Fetching 미래에셋비전스팩4호 (477380)...
# Fetching 루트락 (253610)...
# Fetching 스타에스엠리츠 (204210)...
# Fetching 노블엠앤비 (106520)...
# Fetching 디지아이 (043360)...
# Fetching 한솔인티큐브 (070590)...
# Fetching 인베니아 (079950)...
# Fetching 더코디 (224060)...
# Fetching 솔루스첨단소재2우B (33637L)...
# Fetching 케이엠제약 (225430)...
# Fetching 상지건설 (042940)...
# Fetching 대신밸런스제16호스팩 (457630)...
# Fetching 덕성우 (004835)...
# Fetching 뉴보텍 (060260)...
# Fetching 창대정밀 (368030)...
# Fetching 에이치엠씨제7호스팩 (477340)...
# Fetching 광동헬스바이오 (086220)...
# Fetching 대한제당우 (001795)...
# Fetching 퀀텀온 (227100)...
# Fetching 디에이치엑스컴퍼니 (031860)...
# Fetching 하나30호스팩 (469880)...
# Fetching 하나28호스팩 (454750)...
# Fetching 태양금속우 (004105)...
# Fetching 신영스팩8호 (430220)...
# Fetching 대신밸런스제14호스팩 (442310)...
# Fetching 유안타제15호스팩 (473050)...
# Fetching 에이리츠 (140910)...
# Fetching 한국제15호스팩 (479880)...
# Fetching 미래에셋비전스팩6호 (478440)...
# Fetching 이비테크 (208850)...
# Fetching 예선테크 (250930)...
# Fetching 엔에스엠 (238170)...
# Fetching 비엘팜텍 (065170)...
# Fetching 바이온 (032980)...
# Fetching 길교이앤씨 (456700)...
# Fetching 비케이홀딩스 (050090)...
# Fetching 키움제11호스팩 (489480)...
# Fetching 일정실업 (008500)...
# Fetching 이노벡스 (279060)...
# Fetching 파커스 (065690)...
# Fetching 한국제14호스팩 (477530)...
# Fetching 대신밸런스제17호스팩 (471050)...
# Fetching 아퓨어스 (149300)...
# Fetching 대동고려삼 (178600)...
# Fetching 엔에이치스팩31호 (481890)...
# Fetching NPC우 (004255)...
# Fetching JW중외제약2우B (001067)...
# Fetching KB제29호스팩 (478390)...
# Fetching 태양3C (052960)...
# Fetching 한진칼우 (18064K)...
# Fetching 엔에스컴퍼니 (224760)...
# Fetching 디비금융제13호스팩 (489730)...
# Fetching 에이디칩스 (054630)...
# Fetching 하나26호스팩 (446750)...
# Fetching 엄지하우스 (224810)...
# Fetching 키움제8호스팩 (446840)...
# Fetching KB제31호스팩 (492220)...
# Fetching 광진실업 (026910)...
# Fetching 삼영이엔씨 (065570)...
# Fetching 교보16호스팩 (482520)...
# Fetching 켈스 (402420)...
# Fetching 아이엠 (101390)...
# Fetching 유안타제10호스팩 (435380)...
# Fetching 이앤에치 (341310)...
# Fetching DB금융스팩11호 (456440)...
# Fetching DB금융스팩12호 (477760)...
# Fetching KD (044180)...
# Fetching 나눔테크 (244880)...
# Fetching LX홀딩스1우 (38380K)...
# Fetching 하나27호스팩 (448370)...
# Fetching 장원테크 (174880)...
# Fetching 신영스팩9호 (445970)...
# Fetching KB제28호스팩 (476470)...
# Fetching 대신밸런스제19호스팩 (482690)...
# Fetching 코오롱글로벌우 (003075)...
# Fetching 신한제12호스팩 (474660)...
# Fetching 하나31호스팩 (469900)...
# Fetching 신한제14호스팩 (487360)...
# Fetching 하나29호스팩 (454640)...
# Fetching 코오롱모빌리티그룹우 (45014K)...
# Fetching 미래에셋비전스팩5호 (477470)...
# Fetching 넥센우 (005725)...
# Fetching 유안타제16호스팩 (474490)...
# Fetching 유안타제9호스팩 (430700)...
# Fetching 로보쓰리에이아이 (238500)...
# Fetching 유유제약1우 (000225)...
# Fetching 삼양사우 (145995)...
# Fetching 대원전선우 (006345)...
# Fetching KB제30호스팩 (486630)...
# Fetching 미래에셋비전스팩2호 (446190)...
# Fetching 엔에이치스팩24호 (437780)...
# Fetching 유안타제11호스팩 (444920)...
# Fetching 판도라티비 (202960)...
# Fetching 유안타제17호스팩 (493790)...
# Fetching 미래에셋비전스팩3호 (448830)...
# Fetching 에스케이증권제9호스팩 (455910)...
# Fetching 상상인제4호스팩 (452670)...
# Fetching 하이제8호스팩 (450050)...
# Fetching 바이오인프라생명과학 (266470)...
# Fetching 오늘이엔엠 (192410)...
# Fetching 유안타제12호스팩 (446150)...
# Fetching 올리패스 (244460)...
# Fetching 교보17호스팩 (489210)...
# Fetching 대주이엔티 (114920)...
# Fetching 한화플러스제4호스팩 (455310)...
# Fetching 이베스트스팩6호 (478110)...
# Fetching 타임기술 (318660)...
# Fetching 신영스팩10호 (472220)...
# Fetching IBKS제22호스팩 (448760)...
# Fetching 해성산업1우 (03481K)...
# Fetching JW중외제약우 (001065)...
# Fetching 유진스팩11호 (488060)...
# Fetching 제이엠멀티 (254160)...
# Fetching 질경이 (233990)...
# Fetching 유안타제14호스팩 (450940)...
# Fetching 한국제13호스팩 (464440)...
# Fetching 하나34호스팩 (484130)...
# Fetching 비엔케이제1호스팩 (445360)...
# Fetching IBKS제20호스팩 (439730)...
# Fetching KC산업 (112190)...
# Fetching IBKS제21호스팩 (442770)...
# Fetching KB제25호스팩 (455250)...
# Fetching 한국제12호스팩 (458610)...
# Fetching IBKS제24호스팩 (469480)...
# Fetching IBKS제23호스팩 (467930)...
# Fetching 에스케이증권제13호스팩 (473950)...
# Fetching 교보14호스팩 (456490)...
# Fetching 유진스팩10호 (468760)...
# Fetching 지앤이헬스케어 (299480)...
# Fetching 코셋 (189350)...
# Fetching 대덕1우 (00806K)...
# Fetching 에이원알폼 (234070)...
# Fetching 신한제15호스팩 (487830)...
# Fetching 에이치엠씨제6호스팩 (462020)...
# Fetching 교보13호스팩 (440790)...
# Fetching 키움제10호스팩 (487720)...
# Fetching 아이오바이오 (447690)...
# Fetching 퓨쳐메디신 (341170)...
# Fetching 에스케이증권제11호스팩 (472230)...
# Fetching 비엔케이제2호스팩 (473370)...
# Fetching 씨앗 (103660)...
# Fetching 큐로홀딩스 (051780)...
# Fetching 바이오프로테크 (199290)...
# Fetching 한국패러랠 (168490)...
# Fetching 오건에코텍 (212310)...
# Fetching 수프로 (185190)...
# Fetching 성신양회우 (004985)...
# Fetching 한화우 (000885)...
# Fetching 메디젠휴먼케어 (236340)...
# Fetching 럭스피아 (092590)...
# Fetching 교보15호스팩 (465320)...
# Fetching 제노텍 (066830)...
# Fetching 에스케이증권제8호스팩 (435870)...
# Fetching 신한제10호스팩 (418210)...
# Fetching 하나33호스팩 (475250)...
# Fetching 신한제13호스팩 (474930)...
# Fetching 유진스팩9호 (442130)...
# Fetching 투비소프트 (079970)...
# Fetching 크라운제과우 (26490K)...
# Fetching 한화갤러리아우 (45226K)...
# Fetching 엠에프엠코리아 (323230)...
# Fetching 에스케이증권제10호스팩 (457940)...
# Fetching 에스케이증권제12호스팩 (473000)...
# Fetching 하나32호스팩 (475240)...
# Fetching 노루홀딩스우 (000325)...
# Fetching SK증권우 (001515)...
# Fetching 유니포인트 (121060)...
# Fetching 에스엘테라퓨틱스 (258540)...
# Fetching 엔에이치스팩25호 (438580)...
# Fetching 마이크로엔엑스 (448780)...
# Fetching 한양증권우 (001755)...
# Fetching 타이드 (346010)...
# Fetching 더테크놀로지 (043090)...
# Fetching 노루페인트우 (090355)...
# Fetching 에스제이켐 (217910)...
# Fetching 태양기계 (116100)...
# Fetching 노보믹스 (283100)...
# Fetching 일양약품우 (007575)...
# Fetching 가이아코퍼레이션 (296520)...
# Fetching 하이트진로홀딩스우 (000145)...
# Fetching 티와이홀딩스우 (36328K)...
# Fetching 동원시스템즈우 (014825)...
# Fetching 팡스카이 (266350)...
# Fetching 크라운해태홀딩스우 (005745)...
# Fetching 파워풀엑스 (266870)...
# Fetching 남선알미우 (008355)...
# Fetching 미래엔에듀파트너 (208890)...
# Fetching 뿌리깊은나무들 (266170)...
# Fetching 큐러블 (086460)...
# Fetching 엘리비젼 (276240)...
# Fetching 동부건설우 (005965)...
# Fetching 깨끗한나라우 (004545)...
# Fetching 코리아써키트2우B (00781K)...
# Fetching 흥국화재우 (000545)...
# Fetching CNH (023460)...
# Fetching 계양전기우 (012205)...
# Fetching 오션스바이오 (332190)...
# Fetching 금강공업우 (014285)...
# Fetching 금호건설우 (002995)...
# Fetching 태영건설우 (009415)...
# Fetching CJ씨푸드1우 (011155)...
# Fetching 유유제약2우B (000227)...
# Fetching 에이아이더뉴트리진 (311960)...
# Fetching 성문전자우 (014915)...
# Fetching 동양우 (001525)...
# Fetching 진흥기업2우B (002787)...
# Fetching 서울식품우 (004415)...
# Fetching 진흥기업우B (002785)...
# Fetching 소프트센우 (032685)...
# Fetching 큐엠씨 (136660)...
# Fetching 동양2우B (001527)...
# Fetching 대호특수강우 (021045)...
# Fetching 크로넥스 (215570)...
# Fetching 씨알푸드 (236030)...
# Fetching 테크트랜스 (258050)...
# Fetching 나라소프트 (288490)...
# Fetching 위월드 (140660)...
# Fetching 씨앤에스링크 (245450)...
# Fetching 테크엔 (308700)...
# Fetching 썬테크 (217320)...
# Fetching 티엘엔지니어링 (413300)...
# CSV 저장 완료: krx_stock_data.csv

# %%
import requests
import json
import os
from datetime import datetime, timedelta
from dotenv import load_dotenv

load_dotenv()

APP_KEY = os.getenv("KIS_APP_KEY")
APP_SECRET = os.getenv("KIS_APP_SECRET")

TOKEN_FILE = "access_token.json"

def save_token(token, expires_in):
    """ 토큰과 만료시간을 파일에 저장 """
    # expires_in(초) 값을 기준으로 만료시간 계산 (보통 1일 = 86400초)
    expiration = datetime.now() + timedelta(seconds=expires_in)
    data = {"token": token, "expiration": expiration.isoformat()}
    with open(TOKEN_FILE, "w") as f:
        json.dump(data, f)

def load_token():
    """ 저장된 토큰을 파일에서 읽어오고, 아직 유효하면 반환 """
    try:
        with open(TOKEN_FILE, "r") as f:
            data = json.load(f)
        expiration = datetime.fromisoformat(data["expiration"])
        if datetime.now() < expiration:
            return data["token"]
        else:
            return None
    except Exception as e:
        # 파일이 없거나 형식이 잘못된 경우
        return None

def get_access_token():
    """ 한국투자증권 Open API Access Token 요청 및 캐시된 토큰 사용 """
    # 먼저 저장된 토큰이 있는지 확인
    token = load_token()
    if token:
        print("✅ 저장된 Access Token 사용")
        return token

    # 토큰이 없거나 만료되었으면 새로 요청
    url = "https://openapi.koreainvestment.com:9443/oauth2/tokenP"
    headers = {"content-type": "application/json"}
    payload = {
        "grant_type": "client_credentials",
        "appkey": APP_KEY,
        "appsecret": APP_SECRET
    }
    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    token = data.get("access_token")
    # API 문서에서 만료시간 관련 항목이 있으면 사용 (없으면 기본값 86400초 사용)
    expires_in = int(data.get("expires_in", 86400))
    
    if token:
        print(f"✅ Access Token 발급 성공: {token}")
        save_token(token, expires_in)
        return token
    else:
        print(f"❌ Access Token 발급 실패: {data}")
        return None

def get_stock_price(stock_code):
    """ 특정 종목의 현재가 조회 """
    access_token = get_access_token()
    if not access_token:
        return None

    url = "https://openapi.koreainvestment.com:9443/uapi/domestic-stock/v1/quotations/inquire-price"
    
    headers = {
        "Content-Type": "application/json",
        "authorization": f"Bearer {access_token}",
        "appkey": APP_KEY,
        "appsecret": APP_SECRET,
        "tr_id": "FHKST01010100"
    }
    
    params = {
        "fid_cond_mrkt_div_code": "J",
        "fid_input_iscd": stock_code
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()
    
    if "output" in data:
        output = data["output"]
        return {
            "symbol": stock_code,
            "price": output["stck_prpr"],
            "high": output["stck_hgpr"],
            "low": output["stck_lwpr"],
            "volume": output["acml_vol"]
        }
    else:
        print(f"❌ 데이터 조회 실패: {data}")
        return None
# Out:
# ✅ Access Token 발급 성공: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6IjZmNGU4MmRlLTkyMTMtNGM1Mi1hODI0LTY5MWZlMWRhYzgxZSIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc0MjIwMzE0MiwiaWF0IjoxNzQyMTE2NzQyLCJqdGkiOiJQUzBLdFJIclNTT2ZuZTE0elJySFpCczkwc1ZkSExlM1p1RE4ifQ.pM12ULX27znISHhJth3FWBiHI94vmOrGJHGpY8sb8qsPmHtC9zNmWBmPPKpiRsqsX-bIjmpr7WJpTEE8n-yDcQ
# 현재 토큰: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6IjZmNGU4MmRlLTkyMTMtNGM1Mi1hODI0LTY5MWZlMWRhYzgxZSIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc0MjIwMzE0MiwiaWF0IjoxNzQyMTE2NzQyLCJqdGkiOiJQUzBLdFJIclNTT2ZuZTE0elJySFpCczkwc1ZkSExlM1p1RE4ifQ.pM12ULX27znISHhJth3FWBiHI94vmOrGJHGpY8sb8qsPmHtC9zNmWBmPPKpiRsqsX-bIjmpr7WJpTEE8n-yDcQ

# %%
from sqlalchemy import create_engine
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()

DB_URI = os.getenv("DB_URI")

def save_stock_price_to_db(data):
    """ 주식 가격 데이터를 DB에 저장 """
    engine = create_engine(DB_URI)
    
    if data:
        df = pd.DataFrame([data])
        df.to_sql("stock_prices", con=engine, if_exists="append", index=False)
        print(f"✅ {data['symbol']} 데이터 저장 완료!")
    else:
        print("❌ 저장할 데이터가 없습니다.")

# %%
def fetch_and_save_stock():
    """ KIS API에서 주식 가격을 가져와 DB에 저장 """
    stock_list = ["005930", "000660"]  # 삼성전자, SK하이닉스
    for stock in stock_list:
        data = get_stock_price(stock)
        print(data)

# %%
fetch_and_save_stock()
# Out:
# ✅ 저장된 Access Token 사용
# {'symbol': '005930', 'price': '54700', 'high': '55100', 'low': '54400', 'volume': '10845154'}
# ✅ 저장된 Access Token 사용
# {'symbol': '000660', 'price': '204500', 'high': '206000', 'low': '198500', 'volume': '3397462'}
